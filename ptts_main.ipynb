# %%
import modelscope
# Out:
# 2023-08-14 21:49:31,087 - modelscope - INFO - PyTorch version 2.0.1+cpu Found.
# 2023-08-14 21:49:31,090 - modelscope - INFO - Loading ast index from /mnt/workspace/.cache/modelscope/ast_indexer
# 2023-08-14 21:49:31,090 - modelscope - INFO - No valid ast index found from /mnt/workspace/.cache/modelscope/ast_indexer, generating ast index from prebuilt!
# 2023-08-14 21:49:31,139 - modelscope - INFO - Loading done! Current index file version is 1.8.1, with md5 7e951ed23488455ee03049952a2ff64b and a total number of 893 components indexed

# %%
modelscope.__version__
# Out:
# '1.8.1'

# %%
import tts_autolabel

# %%
from modelscope.tools import run_auto_label

input_wav = "./test_wavs/"
output_data = "./output_training_data/"

ret, report = run_auto_label(input_wav=input_wav, work_dir=output_data, resource_revision="v1.0.7")
# Out:
# 2023-08-14 22:58:15,889 - modelscope - INFO - Use user-specified model revision: v1.0.7
# INFO:root:--- Remove /mnt/workspace/ptts/output_training_data/paragraph/prosody folder!  ---
# INFO:root:---  New folder /mnt/workspace/ptts/output_training_data/paragraph/prosody...  ---
# INFO:root:---  OK  ---
# INFO:root:---  New folder /mnt/workspace/ptts/output_training_data/wav...  ---
# INFO:root:---  OK  ---
# INFO:root:--- Remove /mnt/workspace/ptts/output_training_data/log folder!  ---
# INFO:root:---  New folder /mnt/workspace/ptts/output_training_data/log...  ---
# INFO:root:---  OK  ---
# INFO:root:2023-08-14 22:58:22
# INFO:root:TTS-AutoLabeling version: 1.1.7
# INFO:root:wav_preprocess start...
# INFO:root:---  There is this folder!  ---
# 100%|██████████| 1/1 [00:00<00:00, 21509.25it/s]
# 0it [00:00, ?it/s]
# 100%|██████████| 20/20 [00:00<00:00, 203.55it/s]
# INFO:root:[VAD] chunk recordings for training.
# INFO:root:wav cut by vad start...
#   0%|          | 0/20 [00:00<?, ?it/s]INFO:root:wav 01_000018_S0000 is no need to cut
# INFO:root:wav 01_000013_S0000 is no need to cut
# INFO:root:wav 01_000012_S0000 is no need to cut
# INFO:root:wav 01_000016_S0000 is no need to cut
# INFO:root:wav 01_000010_S0000 is no need to cut
# INFO:root:wav 01_000005_S0000 is no need to cut
# INFO:root:wav 01_000014_S0000 is no need to cut
#  35%|███▌      | 7/20 [00:00<00:00, 66.38it/s]INFO:root:wav 01_000001_S0000 is no need to cut
# INFO:root:wav 01_000015_S0000 is no need to cut
# INFO:root:wav 01_000009_S0000 is no need to cut
# INFO:root:wav 01_000002_S0000 is no need to cut
# INFO:root:wav 01_000011_S0000 is no need to cut
# INFO:root:wav 01_000020_S0000 is no need to cut
# INFO:root:wav 01_000007_S0000 is no need to cut
# INFO:root:wav 01_000006_S0000 is no need to cut
# INFO:root:wav 01_000019_S0000 is no need to cut
#  80%|████████  | 16/20 [00:00<00:00, 76.28it/s]INFO:root:wav 01_000017_S0000 is no need to cut
# INFO:root:wav 01_000003_S0000 is no need to cut
# INFO:root:wav 01_000004_S0000 is no need to cut
# INFO:root:wav 01_000008_S0000 is no need to cut
# 100%|██████████| 20/20 [00:00<00:00, 75.60it/s]
# 100%|██████████| 20/20 [00:00<00:00, 31.40it/s]
# INFO:root:Text to label start...
# text.cc: festival_Text_init
# 100%|██████████| 20/20 [00:02<00:00,  9.83it/s]
# INFO:root:pre-break recording in paragraph by vad.
# INFO:root:Generate phone interval by fa align.
# INFO:root:prosody_dir=/mnt/workspace/ptts/output_training_data/paragraph/prosody
# INFO:root:FA processing...
# INFO:root:---  New folder /mnt/workspace/ptts/output_training_data/raw_ali...  ---
# INFO:root:---  OK  ---
# INFO:root:---  New folder /mnt/workspace/ptts/output_training_data/raw_interval...  ---
# INFO:root:---  OK  ---
#   0%|          | 0/20 [00:00<?, ?it/s]INFO:root:wav: /mnt/workspace/ptts/output_training_data/wav_cut/01_000002_S0000.wav, text: 它是 月球上 唯一 一个 人类
# avr_tok:32, max_tok:52, avr_wbtok:1, max_wbtok:4, avr_wetok:2, max_wetok:4, avr_we_arc 2 avr_lmcall:2 p2, avr_histbeam:150.000000, max_histbeam:150.000000, avr_wbhistbeam:100.000000, max_wbhistbeam:100.000000
# INFO:root:wav: /mnt/workspace/ptts/output_training_data/wav_cut/01_000019_S0000.wav, text: 天天 跑步 锻炼
# avr_tok:30, max_tok:39, avr_wbtok:2, max_wbtok:3, avr_wetok:2, max_wetok:4, avr_we_arc 2 avr_lmcall:2 p2, avr_histbeam:150.000000, max_histbeam:150.000000, avr_wbhistbeam:100.000000, max_wbhistbeam:100.000000
# INFO:root:wav: /mnt/workspace/ptts/output_training_data/wav_cut/01_000018_S0000.wav, text: 身体 也 出了 问题
# avr_tok:28, max_tok:46, avr_wbtok:2, max_wbtok:3, avr_wetok:1, max_wetok:3, avr_we_arc 1 avr_lmcall:1 p1, avr_histbeam:150.000000, max_histbeam:150.000000, avr_wbhistbeam:100.000000, max_wbhistbeam:100.000000
#  15%|█▌        | 3/20 [00:00<00:00, 24.49it/s]INFO:root:wav: /mnt/workspace/ptts/output_training_data/wav_cut/01_000005_S0000.wav, text: 就是 每天 开采 月球 矿石 发射到 地球
# avr_tok:28, max_tok:49, avr_wbtok:1, max_wbtok:4, avr_wetok:1, max_wetok:3, avr_we_arc 1 avr_lmcall:1 p1, avr_histbeam:150.000000, max_histbeam:150.000000, avr_wbhistbeam:100.000000, max_wbhistbeam:100.000000
# INFO:root:wav: /mnt/workspace/ptts/output_training_data/wav_cut/01_000014_S0000.wav, text: 每天 晚上 做的 梦
# avr_tok:36, max_tok:76, avr_wbtok:2, max_wbtok:5, avr_wetok:3, max_wetok:9, avr_we_arc 3 avr_lmcall:3 p3, avr_histbeam:150.000000, max_histbeam:150.000000, avr_wbhistbeam:100.000000, max_wbhistbeam:100.000000
# INFO:root:wav: /mnt/workspace/ptts/output_training_data/wav_cut/01_000016_S0000.wav, text: 最近 他 发现
# avr_tok:24, max_tok:40, avr_wbtok:2, max_wbtok:3, avr_wetok:1, max_wetok:3, avr_we_arc 1 avr_lmcall:1 p1, avr_histbeam:150.000000, max_histbeam:150.000000, avr_wbhistbeam:100.000000, max_wbhistbeam:100.000000
#  30%|███       | 6/20 [00:00<00:00, 26.68it/s]INFO:root:wav: /mnt/workspace/ptts/output_training_data/wav_cut/01_000003_S0000.wav, text: 已经 独自 呆了 一千零八十天
# avr_tok:26, max_tok:47, avr_wbtok:1, max_wbtok:3, avr_wetok:1, max_wetok:3, avr_we_arc 1 avr_lmcall:1 p1, avr_histbeam:150.000000, max_histbeam:150.000000, avr_wbhistbeam:100.000000, max_wbhistbeam:100.000000
# INFO:root:wav: /mnt/workspace/ptts/output_training_data/wav_cut/01_000011_S0000.wav, text: 还教 他们 谈 恋爱
# avr_tok:30, max_tok:49, avr_wbtok:2, max_wbtok:4, avr_wetok:2, max_wetok:3, avr_we_arc 2 avr_lmcall:2 p2, avr_histbeam:150.000000, max_histbeam:150.000000, avr_wbhistbeam:100.000000, max_wbhistbeam:100.000000
# INFO:root:wav: /mnt/workspace/ptts/output_training_data/wav_cut/01_000017_S0000.wav, text: 自己 不断 精神 出 问题
# avr_tok:29, max_tok:47, avr_wbtok:1, max_wbtok:3, avr_wetok:2, max_wetok:4, avr_we_arc 2 avr_lmcall:2 p2, avr_histbeam:150.000000, max_histbeam:150.000000, avr_wbhistbeam:100.000000, max_wbhistbeam:100.000000
#  45%|████▌     | 9/20 [00:00<00:00, 27.28it/s]INFO:root:wav: /mnt/workspace/ptts/output_training_data/wav_cut/01_000006_S0000.wav, text: 如今的 他
# avr_tok:32, max_tok:55, avr_wbtok:1, max_wbtok:3, avr_wetok:3, max_wetok:7, avr_we_arc 3 avr_lmcall:3 p3, avr_histbeam:150.000000, max_histbeam:150.000000, avr_wbhistbeam:100.000000, max_wbhistbeam:100.000000
# INFO:root:wav: /mnt/workspace/ptts/output_training_data/wav_cut/01_000001_S0000.wav, text: 长久的 孤独 会 让人 发疯芒
# avr_tok:37, max_tok:76, avr_wbtok:1, max_wbtok:3, avr_wetok:3, max_wetok:8, avr_we_arc 3 avr_lmcall:3 p3, avr_histbeam:150.000000, max_histbeam:150.000000, avr_wbhistbeam:100.000000, max_wbhistbeam:100.000000
# INFO:root:wav: /mnt/workspace/ptts/output_training_data/wav_cut/01_000012_S0000.wav, text: 他会 看见 幻局
# avr_tok:26, max_tok:48, avr_wbtok:1, max_wbtok:3, avr_wetok:2, max_wetok:4, avr_we_arc 2 avr_lmcall:2 p2, avr_histbeam:150.000000, max_histbeam:150.000000, avr_wbhistbeam:100.000000, max_wbhistbeam:100.000000
# INFO:root:wav: /mnt/workspace/ptts/output_training_data/wav_cut/01_000020_S0000.wav, text: 居然 也 喘的 越来越 厉害
# avr_tok:38, max_tok:71, avr_wbtok:2, max_wbtok:3, avr_wetok:3, max_wetok:8, avr_we_arc 3 avr_lmcall:3 p3, avr_histbeam:150.000000, max_histbeam:150.000000, avr_wbhistbeam:100.000000, max_wbhistbeam:100.000000
#  65%|██████▌   | 13/20 [00:00<00:00, 28.70it/s]INFO:root:wav: /mnt/workspace/ptts/output_training_data/wav_cut/01_000015_S0000.wav, text: 都 来自 春天
# avr_tok:26, max_tok:47, avr_wbtok:2, max_wbtok:3, avr_wetok:1, max_wetok:3, avr_we_arc 2 avr_lmcall:2 p2, avr_histbeam:150.000000, max_histbeam:150.000000, avr_wbhistbeam:100.000000, max_wbhistbeam:100.000000
# INFO:root:wav: /mnt/workspace/ptts/output_training_data/wav_cut/01_000013_S0000.wav, text: 大美女 凭空 出现 然后 又 消失
# avr_tok:36, max_tok:88, avr_wbtok:1, max_wbtok:4, avr_wetok:1, max_wetok:3, avr_we_arc 2 avr_lmcall:2 p2, avr_histbeam:150.000000, max_histbeam:150.000000, avr_wbhistbeam:100.000000, max_wbhistbeam:100.000000
# INFO:root:wav: /mnt/workspace/ptts/output_training_data/wav_cut/01_000010_S0000.wav, text: 给 自己 种的 花草 命名
# avr_tok:45, max_tok:95, avr_wbtok:2, max_wbtok:4, avr_wetok:3, max_wetok:8, avr_we_arc 7 avr_lmcall:7 p7, avr_histbeam:150.000000, max_histbeam:150.000000, avr_wbhistbeam:100.000000, max_wbhistbeam:100.000000
# INFO:root:wav: /mnt/workspace/ptts/output_training_data/wav_cut/01_000004_S0000.wav, text: 他的 工作 枯燥 单调
# avr_tok:27, max_tok:44, avr_wbtok:2, max_wbtok:4, avr_wetok:1, max_wetok:3, avr_we_arc 1 avr_lmcall:1 p1, avr_histbeam:150.000000, max_histbeam:150.000000, avr_wbhistbeam:100.000000, max_wbhistbeam:100.000000
#  85%|████████▌ | 17/20 [00:00<00:00, 29.74it/s]INFO:root:wav: /mnt/workspace/ptts/output_training_data/wav_cut/01_000009_S0000.wav, text: 会 一天到晚 都 自言自语
# avr_tok:30, max_tok:49, avr_wbtok:1, max_wbtok:3, avr_wetok:1, max_wetok:3, avr_we_arc 2 avr_lmcall:2 p2, avr_histbeam:150.000000, max_histbeam:150.000000, avr_wbhistbeam:100.000000, max_wbhistbeam:100.000000
# INFO:root:wav: /mnt/workspace/ptts/output_training_data/wav_cut/01_000007_S0000.wav, text: 长发 长须
# avr_tok:23, max_tok:41, avr_wbtok:1, max_wbtok:3, avr_wetok:1, max_wetok:3, avr_we_arc 1 avr_lmcall:1 p1, avr_histbeam:150.000000, max_histbeam:150.000000, avr_wbhistbeam:100.000000, max_wbhistbeam:100.000000
# INFO:root:wav: /mnt/workspace/ptts/output_training_data/wav_cut/01_000008_S0000.wav, text: 不修 蝙蝠
# avr_tok:23, max_tok:42, avr_wbtok:2, max_wbtok:3, avr_wetok:1, max_wetok:2, avr_we_arc 1 avr_lmcall:1 p1, avr_histbeam:150.000000, max_histbeam:150.000000, avr_wbhistbeam:100.000000, max_wbhistbeam:100.000000
# 100%|██████████| 20/20 [00:00<00:00, 29.69it/s]
# INFO:root:---  There is this folder!  ---
# INFO:root:01_000001_S0000.ali
# INFO:root:01_000009_S0000.ali
# INFO:root:01_000002_S0000.ali
# INFO:root:01_000006_S0000.ali
# INFO:root:01_000018_S0000.ali
# INFO:root:01_000019_S0000.ali
# INFO:root:01_000005_S0000.ali
# INFO:root:01_000014_S0000.ali
# INFO:root:01_000010_S0000.ali
# INFO:root:01_000004_S0000.ali
# INFO:root:01_000015_S0000.ali
# INFO:root:01_000003_S0000.ali
# INFO:root:01_000008_S0000.ali
# INFO:root:01_000012_S0000.ali
# INFO:root:01_000011_S0000.ali
# INFO:root:01_000020_S0000.ali
# INFO:root:01_000013_S0000.ali
# INFO:root:01_000017_S0000.ali
# INFO:root:01_000007_S0000.ali
# INFO:root:01_000016_S0000.ali
# INFO:root:---  New folder /mnt/workspace/ptts/output_training_data/ali...  ---
# INFO:root:---  OK  ---
# INFO:root:---  New folder /mnt/workspace/ptts/output_training_data/coarse_interval...  ---
# INFO:root:---  OK  ---
# INFO:root:Trim silence wav with align info and modify wav files....
# 100%|██████████| 20/20 [00:00<00:00, 540.96it/s]
# INFO:root:Convert align info to interval files....
# INFO:root:---  There is this folder!  ---
# INFO:root:01_000001_S0000.ali
# INFO:root:01_000009_S0000.ali
# INFO:root:01_000002_S0000.ali
# INFO:root:01_000006_S0000.ali
# INFO:root:01_000018_S0000.ali
# INFO:root:01_000019_S0000.ali
# INFO:root:01_000005_S0000.ali
# INFO:root:01_000014_S0000.ali
# INFO:root:01_000010_S0000.ali
# INFO:root:01_000004_S0000.ali
# INFO:root:01_000015_S0000.ali
# INFO:root:01_000003_S0000.ali
# INFO:root:01_000008_S0000.ali
# INFO:root:01_000012_S0000.ali
# INFO:root:01_000011_S0000.ali
# INFO:root:01_000020_S0000.ali
# INFO:root:01_000013_S0000.ali
# INFO:root:01_000017_S0000.ali
# INFO:root:01_000007_S0000.ali
# INFO:root:01_000016_S0000.ali
# INFO:root:qualification review.
# INFO:root:prosody sillence detect.
# INFO:root:---  New folder /mnt/workspace/ptts/output_training_data/prosody...  ---
# INFO:root:---  OK  ---
# INFO:root:average silence duration: 0.09500000000000008
# 100%|██████████| 40/40 [00:00<00:00, 20638.72it/s]
# INFO:root:Write prosody file
# INFO:root:0 "mismatch" sentences
#
# INFO:root:Auto labeling info: stage 1 | develop mode 0 | gender:female | score 10.000000 | retcode 0
# INFO:root:labeling report:
# INFO:root:stage 1 | develop mode 0 | gender female | score 10.000000 | retcode 0
# INFO:root:qulification report:
# INFO:root:credit score: 10.000000
# INFO:root:qualified score: 3.000000
# INFO:root:normalized snr: 35.000000
# INFO:root:abandon utt snr threshold: 10.000000
# INFO:root:snr score ration: 0.500000
# INFO:root:interval score ration: 0.500000
# INFO:root:data qulificaion report:

# %%
from modelscope.metainfo import Trainers
from modelscope.trainers import build_trainer
from modelscope.utils.audio.audio_utils import TtsTrainType

pretrained_model_id = 'damo/speech_personal_sambert-hifigan_nsf_tts_zh-cn_pretrain_16k'

dataset_id = "./output_training_data/"
pretrain_work_dir = "./pretrain_work_dir/"
        
# 训练信息，用于指定需要训练哪个或哪些模型，这里展示AM和Vocoder模型皆进行训练
# 目前支持训练：TtsTrainType.TRAIN_TYPE_SAMBERT, TtsTrainType.TRAIN_TYPE_VOC
# 训练SAMBERT会以模型最新step作为基础进行finetune
train_info = {
    TtsTrainType.TRAIN_TYPE_SAMBERT: {  # 配置训练AM（sambert）模型
        'train_steps': 202,               # 训练多少个step 
        'save_interval_steps': 200,       # 每训练多少个step保存一次checkpoint
        'log_interval': 10               # 每训练多少个step打印一次训练日志
    }
}

# 配置训练参数，指定数据集，临时工作目录和train_info
kwargs = dict(
    model=pretrained_model_id,                  # 指定要finetune的模型
    model_revision = "v1.0.6",
    work_dir=pretrain_work_dir,                 # 指定临时工作目录
    train_dataset=dataset_id,                   # 指定数据集id
    train_type=train_info                       # 指定要训练类型及参数
)

trainer = build_trainer(Trainers.speech_kantts_trainer,
                        default_args=kwargs)

trainer.train()
# Out:
# 2023-08-14 23:01:25,485 - modelscope - INFO - Use user-specified model revision: v1.0.6
# 2023-08-14 23:01:26,380 - modelscope - INFO - Use user-specified model revision: v1.0.6
# 2023-08-14 23:01:27,088 - modelscope - INFO - Set workdir to ./pretrain_work_dir/
# 2023-08-14 23:01:27,089 - modelscope - INFO - load ./output_training_data/
# 2023-08-14 23:01:27,253 - modelscope - INFO - Use user-specified model revision: v1.0.6
# 2023-08-14 23:01:28,443 - modelscope - INFO - am_config=./pretrain_work_dir/orig_model/basemodel_16k/sambert/config.yaml voc_config=./pretrain_work_dir/orig_model/basemodel_16k/hifigan/config.yaml
# 2023-08-14 23:01:28,444 - modelscope - INFO - audio_config=./pretrain_work_dir/orig_model/basemodel_16k/audio_config_se_16k.yaml
# 2023-08-14 23:01:28,444 - modelscope - INFO - am_ckpts=OrderedDict([(2400000, './pretrain_work_dir/orig_model/basemodel_16k/sambert/ckpt/checkpoint_2400000.pth')])
# 2023-08-14 23:01:28,445 - modelscope - INFO - voc_ckpts=OrderedDict([(2400000, './pretrain_work_dir/orig_model/basemodel_16k/hifigan/ckpt/checkpoint_2400000.pth')])
# 2023-08-14 23:01:28,445 - modelscope - INFO - se_path=./pretrain_work_dir/orig_model/se.npy se_model_path=./pretrain_work_dir/orig_model/basemodel_16k/speaker_embedding/se.onnx
# 2023-08-14 23:01:28,445 - modelscope - INFO - mvn_path=./pretrain_work_dir/orig_model/mvn.npy
# festival_initialize() called more than once
# Load pinyin_en_mix_dict failed
# Load pinyin_en_mix_dict failed
# Load pinyin_en_mix_dict failed
# Load pinyin_en_mix_dict failed
# Load pinyin_en_mix_dict failed
# Load pinyin_en_mix_dict failed
# Load pinyin_en_mix_dict failed
# Load pinyin_en_mix_dict failed
# Load pinyin_en_mix_dict failed
# Load pinyin_en_mix_dict failed
# Load pinyin_en_mix_dict failed
# Load pinyin_en_mix_dict failed
# Load pinyin_en_mix_dict failed
# Load pinyin_en_mix_dict failed
# Load pinyin_en_mix_dict failed
# Load pinyin_en_mix_dict failed
# 100%|██████████| 40/40 [00:00<00:00, 19418.07it/s]
# INFO:root:TextScriptConvertor.process:
# Save script to: ./pretrain_work_dir/data/Script.xml
# INFO:root:TextScriptConvertor.process:
# Save metafile to: ./pretrain_work_dir/data/raw_metafile.txt
# INFO:root:[AudioProcessor] Initialize AudioProcessor.
# INFO:root:[AudioProcessor] config params:
# INFO:root:[AudioProcessor] wav_normalize: True
# INFO:root:[AudioProcessor] trim_silence: True
# INFO:root:[AudioProcessor] trim_silence_threshold_db: 60
# INFO:root:[AudioProcessor] preemphasize: False
# INFO:root:[AudioProcessor] sampling_rate: 16000
# INFO:root:[AudioProcessor] hop_length: 200
# INFO:root:[AudioProcessor] win_length: 1000
# INFO:root:[AudioProcessor] n_fft: 2048
# INFO:root:[AudioProcessor] n_mels: 80
# INFO:root:[AudioProcessor] fmin: 0.0
# INFO:root:[AudioProcessor] fmax: 8000.0
# INFO:root:[AudioProcessor] phone_level_feature: True
# INFO:root:[AudioProcessor] se_feature: True
# INFO:root:[AudioProcessor] norm_type: mean_std
# INFO:root:[AudioProcessor] max_norm: 1.0
# INFO:root:[AudioProcessor] symmetric: False
# INFO:root:[AudioProcessor] min_level_db: -100.0
# INFO:root:[AudioProcessor] ref_level_db: 20
# INFO:root:[AudioProcessor] num_workers: 16
# INFO:root:[AudioProcessor] Amplitude normalization started
# INFO:root:Volume statistic proceeding...
# 100%|██████████| 20/20 [00:00<00:00, 103.47it/s]
# INFO:root:Average amplitude RMS : 0.05607235000000001
# INFO:root:Volume statistic done.
# INFO:root:Volume normalization proceeding...
# 100%|██████████| 20/20 [00:00<00:00, 3771.01it/s]
# INFO:root:Volume normalization done.
# INFO:root:[AudioProcessor] Amplitude normalization finished
# INFO:root:[AudioProcessor] Duration generation started
#   0%|          | 0/20 [00:00<?, ?it/s]INFO:root:[AudioProcessor] Duration align with mel is proceeding...
# 100%|██████████| 20/20 [00:00<00:00, 114.35it/s]
# INFO:root:[AudioProcessor] Duration generate finished
# INFO:root:[AudioProcessor] Trim silence with interval started
# INFO:root:[AudioProcessor] Start to load pcm from ./pretrain_work_dir/data/wav
# 100%|██████████| 20/20 [00:00<00:00, 122.80it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# 100%|██████████| 20/20 [00:00<00:00, 7567.53it/s]
# INFO:root:[AudioProcessor] Trim silence finished
# INFO:root:[AudioProcessor] Melspec extraction started
# 100%|██████████| 20/20 [00:01<00:00, 10.40it/s]
# INFO:root:[AudioProcessor] Melspec extraction finished
# INFO:root:Melspec statistic proceeding...
# 100%|██████████| 20/20 [00:00<00:00, 35575.10it/s]
# 100%|██████████| 20/20 [00:00<00:00, 17091.70it/s]
# INFO:root:Melspec statistic done
# INFO:root:[AudioProcessor] melspec mean and std saved to:
# ./pretrain_work_dir/data/mel/mel_mean.txt,
# ./pretrain_work_dir/data/mel/mel_std.txt
# INFO:root:[AudioProcessor] Melspec mean std norm is proceeding...
# INFO:root:[AudioProcessor] Melspec normalization finished
# INFO:root:[AudioProcessor] Normed Melspec saved to ./pretrain_work_dir/data/mel
# INFO:root:[AudioProcessor] Pitch extraction started
#   0%|          | 0/20 [00:00<?, ?it/s]INFO:root:[AudioProcessor] Pitch align with mel is proceeding...
# 100%|██████████| 20/20 [00:00<00:00, 89.47it/s]
# INFO:root:[AudioProcessor] Pitch normalization is proceeding...
# 100%|██████████| 20/20 [00:00<00:00, 66208.43it/s]
# 100%|██████████| 20/20 [00:00<00:00, 42153.81it/s]
# INFO:root:[AudioProcessor] f0 mean and std saved to:
# ./pretrain_work_dir/data/f0/f0_mean.txt,
# ./pretrain_work_dir/data/f0/f0_std.txt
# INFO:root:[AudioProcessor] Pitch mean std norm is proceeding...
# INFO:root:[AudioProcessor] Pitch turn to phone-level is proceeding...
# 100%|██████████| 20/20 [00:00<00:00, 124.22it/s]
# INFO:root:[AudioProcessor] Pitch normalization finished
# INFO:root:[AudioProcessor] Normed f0 saved to ./pretrain_work_dir/data/f0
# INFO:root:[AudioProcessor] Pitch extraction finished
# INFO:root:[AudioProcessor] Energy extraction started
# 100%|██████████| 20/20 [00:00<00:00, 109.80it/s]
# 100%|██████████| 20/20 [00:00<00:00, 63453.92it/s]
# 100%|██████████| 20/20 [00:00<00:00, 45491.37it/s]
# INFO:root:[AudioProcessor] energy mean and std saved to:
# ./pretrain_work_dir/data/energy/energy_mean.txt,
# ./pretrain_work_dir/data/energy/energy_std.txt
# INFO:root:[AudioProcessor] Energy mean std norm is proceeding...
# 100%|██████████| 20/20 [00:00<00:00, 123.15it/s]
# INFO:root:[AudioProcessor] Energy normalization finished
# INFO:root:[AudioProcessor] Normed Energy saved to ./pretrain_work_dir/data/energy
# INFO:root:[AudioProcessor] Energy extraction finished
# INFO:root:[AudioProcessor] All features extracted successfully!
# INFO:root:Processing audio done.
# INFO:root:[SpeakerEmbeddingProcessor] Speaker embedding extractor started
# INFO:root:[SpeakerEmbeddingProcessor] se model loading error!!!
# INFO:root:[SpeakerEmbeddingProcessor] please update your se model to ensure that the version is greater than or equal to 1.0.5
# INFO:root:[SpeakerEmbeddingProcessor] try load it as se.model

# %%
import os
from modelscope.models.audio.tts import SambertHifigan
from modelscope.pipelines import pipeline
from modelscope.utils.constant import Tasks

model_dir = os.path.abspath("./pretrain_work_dir")

custom_infer_abs = {
    'voice_name':
    'F7',
    'am_ckpt':
    os.path.join(model_dir, 'tmp_am', 'ckpt'),
    'am_config':
    os.path.join(model_dir, 'tmp_am', 'config.yaml'),
    'voc_ckpt':
    os.path.join(model_dir, 'orig_model', 'basemodel_16k', 'hifigan', 'ckpt'),
    'voc_config':
    os.path.join(model_dir, 'orig_model', 'basemodel_16k', 'hifigan',
             'config.yaml'),
    'audio_config':
    os.path.join(model_dir, 'data', 'audio_config.yaml'),
    'se_file':
    os.path.join(model_dir, 'data', 'se', 'se.npy')
}
kwargs = {'custom_ckpt': custom_infer_abs}

model_id = SambertHifigan(os.path.join(model_dir, "orig_model"), **kwargs)

inference = pipeline(task=Tasks.text_to_speech, model=model_id)
output = inference(input="今天的天气真不错")

import IPython.display as ipd
ipd.Audio(output["output_wav"], rate=16000)
