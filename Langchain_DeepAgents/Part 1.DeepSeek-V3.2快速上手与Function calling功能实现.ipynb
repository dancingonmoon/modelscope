# %% [markdown]
# ## <font face="仿宋">课程说明：

# %% [markdown]
# - 体验课内容节选自[《2025大模型Agent智能体开发实战》(12月班)](https://ix9mq.xetslk.com/s/3qeesJ)完整版付费课程

# %% [markdown]
# &emsp;&emsp;体验课时间有限，若想深度学习大模型技术，欢迎大家报名由我主讲的[《2025大模型Agent智能体开发实战》(12月班)](https://ix9mq.xetslk.com/s/3qeesJ)

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/ac4f2a592e0453c3089da3643ee3404a.png" alt="ac4f2a592e0453c3089da3643ee3404a" style="zoom:33%;" />

# %% [markdown]
# **[《2025大模型Agent智能体开发实战》(12月班)](https://ix9mq.xetslk.com/s/3qeesJ)为【100+小时】体系大课，总共20大模块精讲精析，零基础直达大模型企业级应用！**

# %% [markdown]
# ### <center>课程完整介绍

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/202506172010074.png" alt="a55d48e952ed59f8d93e050594843bc" style="zoom:50%;" />

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/6ee2fbee6b72608bee2888620fac1932.png" alt="6ee2fbee6b72608bee2888620fac1932" style="zoom:50%;" />

# %% [markdown]
# ### <center> 部分课程成果演示

# %%
from IPython.display import Video

# %% [markdown]
# - **Dify+DeepSeek搭建智能微信语音客服**

# %%
Video("https://ml2022.oss-cn-hangzhou.aliyuncs.com/2f1b47f42c65fd59e8d3a83e6cb9f13b_raw.mp4", width=800, height=400)
# Out:
# <video src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/2f1b47f42c65fd59e8d3a83e6cb9f13b_raw.mp4" controls  width="800"  height="400">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# - **Coze自动图文视频创作流程**

# %%
Video("https://ml2022.oss-cn-hangzhou.aliyuncs.com/Coze%E5%8A%A8%E6%80%81%E8%A7%86%E9%A2%91%E7%94%9F%E6%88%90%E5%AE%9E%E4%BE%8B.mp4", width=800, height=400)
# Out:
# <video src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/Coze%E5%8A%A8%E6%80%81%E8%A7%86%E9%A2%91%E7%94%9F%E6%88%90%E5%AE%9E%E4%BE%8B.mp4" controls  width="800"  height="400">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# - **可视化数据分析Multi-Agent**

# %%
Video("https://ml2022.oss-cn-hangzhou.aliyuncs.com/%E5%8F%AF%E8%A7%86%E5%8C%96%E6%95%B0%E6%8D%AE%E5%88%86%E6%9E%90Multi-Agent%E6%95%88%E6%9E%9C%E6%BC%94%E7%A4%BA%E6%95%88%E6%9E%9C.mp4", width=800, height=400)
# Out:
# <video src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/%E5%8F%AF%E8%A7%86%E5%8C%96%E6%95%B0%E6%8D%AE%E5%88%86%E6%9E%90Multi-Agent%E6%95%88%E6%9E%9C%E6%BC%94%E7%A4%BA%E6%95%88%E6%9E%9C.mp4" controls  width="800"  height="400">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# - **高效微调全自动数据集创建**

# %%
Video("https://ml2022.oss-cn-hangzhou.aliyuncs.com/easy_daset_yanshi.mp4", width=800, height=400)
# Out:
# <video src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/easy_daset_yanshi.mp4" controls  width="800"  height="400">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# - **MateGen Pro 项目功能演示**

# %%
Video("https://ml2022.oss-cn-hangzhou.aliyuncs.com/MG%E6%BC%94%E7%A4%BA%E8%A7%86%E9%A2%91.mp4", width=800, height=400)
# Out:
# <video src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/MG%E6%BC%94%E7%A4%BA%E8%A7%86%E9%A2%91.mp4" controls  width="800"  height="400">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# - **智能客服项目展示**

# %%
Video("https://ml2022.oss-cn-hangzhou.aliyuncs.com/%E6%99%BA%E8%83%BD%E5%AE%A2%E6%9C%8D%E6%A1%88%E4%BE%8B%E8%A7%86%E9%A2%91.mp4", width=800, height=400)
# Out:
# <video src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/%E6%99%BA%E8%83%BD%E5%AE%A2%E6%9C%8D%E6%A1%88%E4%BE%8B%E8%A7%86%E9%A2%91.mp4" controls  width="800"  height="400">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# - **GraphRAG+多模态文档检索**

# %%
Video("https://ml2022.oss-cn-hangzhou.aliyuncs.com/7%E6%9C%8817%E6%97%A5%281%29%20%E8%BF%9B%E5%BA%A6%E6%9D%A1.mp4", width=800, height=400)
# Out:
# <video src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/7%E6%9C%8817%E6%97%A5%281%29%20%E8%BF%9B%E5%BA%A6%E6%9D%A1.mp4" controls  width="800"  height="400">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# 此外，若是对大模型底层原理感兴趣，也欢迎报名由我和菜菜老师共同主讲的[《2025大模型原理与实战课程》(秋季班)](https://ix9mq.xetslk.com/s/16asFh)

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/a9c8776df826a9ee8e9fb8e31c72b180.png" alt="a9c8776df826a9ee8e9fb8e31c72b180" style="zoom: 20%;" />

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/3.png" alt="3" style="zoom:50%;" />

# %% [markdown]
# **<span style="color:red;">详细信息扫码添加助教，回复“大模型”，即可领取课程大纲&查看课程详情👇</span>**

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/0.png" alt="0" style="zoom:50%;" />

# %% [markdown]
# ---

# %% [markdown]
# # <center> 国产最强DeepSeek-V3.2 Agent开发实战
# ## <center> Part 1.DeepSeek-V3.2 Agent开发入门

# %% [markdown]
# ## 一、DeepSeek-V3.2模型介绍

# %% [markdown]
# &emsp;&emsp;两个月前，DeepSeek-V3.2-EXP实验版模型正式发布，首次提出了DSA稀疏注意力机制，在维持模型性能不变的情况下，模型推理和训练成本暴降50%以上，

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/image-20251203185936195.png" alt="image-20251203185936195" style="zoom:50%;" />

# %% [markdown]
# 两个月后，DeepSeek-V3.2正式版重磅发布，在实验版基础上，进一步引入可拓展的GRPO训练框架搭配大规模合成Agent任务数据集，借助海量强化学习后训练，让DeepSeek-V3.2正式版模型一举突破性能极限。

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/image-20251203185958235.png" alt="image-20251203185958235" style="zoom:50%;" />

# %% [markdown]
# 模型在数学、编程、Agent性能方面全面领先GPT-5，跻身全球顶尖大模型第一梯队。并且，DeepSeek团队还做了一项大胆的尝试，那就是为模型的训练过程解除思考链长度限制，并同时引入DeepSeekMath-V2提出的自验证数学推理训练法，最终训练得到DeepSeek-V3.2-Speciale模型，更是在各项指标上整体追平全球性能最强大模型Gemini 3.0 Pro。

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/image-20251203190049436.png" alt="image-20251203190049436" style="zoom:50%;" />

# %% [markdown]
# 最重要的是DeepSeek-V3.2模型的价格不到Gemini 3.0的1/5，不到GPT-5.1模型的1/4，可以说性价比拉满。

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/image-20251203190122421.png" alt="image-20251203190122421" style="zoom:33%;" />

# %% [markdown]
# 目前DeepSeek-V3.2和Speciale两款模型的API已全面上线，模型权重也已全面开源，

# %% [markdown]
# - 模型权重：https://huggingface.co/deepseek-ai/DeepSeek-V3.2

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/image-20251203190201357.png" alt="image-20251203190201357" style="zoom:33%;" />

# %% [markdown]
# - DeepSeek模型演化路径

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/image-20251203190321235.png" alt="image-20251203190321235" style="zoom:50%;" />

# %% [markdown]
# - DeepSeek-V3.2核心技术创新点

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/0e6577d1-1753-4b71-aaf7-fb9f03ddc13d.png" alt="0e6577d1-1753-4b71-aaf7-fb9f03ddc13d" style="zoom:55%;" />

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/image-20251203190449545.png" alt="image-20251203190449545" style="zoom:33%;" />

# %% [markdown]
# 而与此同时，DeepSeek-V3.2模型的Agent性能也得到了巨大的提升，和Gemini 3、Claude 4.5等模型的差距已经不到5%。

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/image-20251203190528635.png" alt="image-20251203190528635" style="zoom:50%;" />

# %% [markdown]
# 并且DeepSeek首次引入“思考模式下工具调用”的功能，允许模型在单轮任务调用过程保持多步工具调用思考链记忆，也就是像人一样一边思考一边调用工具，从而大幅提升模型多步调用工具的前后一致性，显著提升模型Agent性能。

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/image-20251203190551647.png" alt="image-20251203190551647" style="zoom:50%;" />

# %% [markdown]
# 而我们团队也对此进行了测试。首先我们将DeepSeek-V3.2模型带入前不久刚开发的生产力级的基于Nano Banana Pro的AI PPT Agent，作为Agent基座模型（注意不是绘图模型），实际运行过程中，无论是多PPT任务拆解、自主提示词编写、还是外部工具调用，都达到了和Gemini 3.0 Pro的同等水平。

# %% [markdown]
# &emsp;&emsp;而除了DeepSeek-V3.2之外，本次DeepSeek还同步开源了一款实验性质的模型，DeepSeek-V3.2-Speciale。这是一次非常大胆的尝试，和DeepSeek-V3.2不同，这款Speciale模型在训练过程中采用了纯推理数据进行训练，并且放宽了普通模型都会有的推理长度惩罚力度，使得Speciale更加擅长通过长思考来解决问题，同时引入了DeepSeekMath-V2提出的自验证数学推理训练法，借助左右互搏来突破数学能力极限。

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/image-20251203190635957.png" alt="image-20251203190635957" style="zoom:50%;" />

# %% [markdown]
# 最终DeepSeek-V3.2-Speciale模型在各主流评测数据集上，无论是数学、编程、还是HLE（人类最后测试）、Agent性能等各个方面，均达到了Gemini 3.0 Pro模型的同等水平。

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/image-20251203190645865.png" alt="image-20251203190645865" style="zoom:50%;" />

# %% [markdown]
# 并且目前Speciale模型权重也已同步开源，而若要调用模型API，则需要更换如图所示的base_url，

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/image-20251203190757545.png" alt="image-20251203190757545" style="zoom:50%;" />

# %% [markdown]
# - 视频地址：https://www.bilibili.com/video/BV13rSHBBEoG/

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/image-20251203185755447.png" alt="image-20251203185755447" style="zoom:33%;" />

# %% [markdown]
# - LangChain 1.0快速入门指南：https://www.bilibili.com/video/BV1uV1yBHE2o/

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/image-20251203190854970.png" alt="image-20251203190854970" style="zoom:33%;" />

# %% [markdown]
# ## 二、DeepSeek快速上手使用

# %% [markdown]
# ### 1.DeepSeek基础调用流程

# %% [markdown]
# &emsp;&emsp;在进行`Agent`开发之前，首先需要准备一个可以进行调用的大模型，这里我们选择使用`DeepSeek`的大模型，并使用`DeepSeek`官方的`API_KEK`进行调用。如果初次使用，需要现在`DeepSeek`官网上进行注册并创建一个新的`API_Key`，其官方地址为：https://platform.deepseek.com/usage

# %% [markdown]
# <div align=center><img src="https://muyu20241105.oss-cn-beijing.aliyuncs.com/images/202506091257041.png" width=60%></div>

# %% [markdown]
# &emsp;&emsp;注册好`DeepSeek`的`API_KEY`后，首先在项目同级目录下创建一个`env`文件，用于存储`DeepSeek`的`API_KEY`，如下所示：

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/image-20251203191005554.png" alt="image-20251203191005554" style="zoom:50%;" />

# %% [markdown]
# &emsp;&emsp;接下来通过`python-dotenv`库读取`env`文件中的`API_KEY`，使其加载到当前的运行环境中，代码如下：

# %%
# ! pip install python-dotenv

# %%
import os
from dotenv import load_dotenv 
load_dotenv(override=True)

DeepSeek_API_KEY = os.getenv("DEEPSEEK_API_KEY")
# print(DeepSeek_API_KEY)  # 可以通过打印查看

# %% [markdown]
# &emsp;&emsp;我们在当前的运行环境下不使用`LangChain`，直接使用`DeepSeek`的`API`进行网络连通性测试，测试代码如下：

# %%
# ! pip install openai

# %%
from openai import OpenAI

# 初始化DeepSeek的API客户端
client = OpenAI(api_key=DeepSeek_API_KEY, base_url="https://api.deepseek.com")

# 调用DeepSeek的API，生成回答
response = client.chat.completions.create(
    model="deepseek-chat",
    messages=[
        {"role": "system", "content": "你是乐于助人的助手，请根据用户的问题给出回答"},
        {"role": "user", "content": "你好，请你介绍一下你自己。"},
    ],
)

# 打印模型最终的响应结果
print(response.choices[0].message.content)
# Out:
# 你好！我是DeepSeek，很高兴认识你！😊
#
# 我是由深度求索公司创造的AI助手，致力于为大家提供热情、贴心的帮助。我有以下几个特点：
#
# 🌟 **能力方面**：
# - 纯文本模型，擅长文字对话、分析和创作
# - 支持文件上传功能，可以处理图像、txt、pdf、ppt、word、excel等文件，并从中读取文字信息
# - 拥有128K的上下文长度，能够处理较长的对话和文档
# - 支持联网搜索功能（需要你在Web/App中手动开启）
#
# 💝 **服务理念**：
# - 完全免费使用，没有任何收费计划
# - 乐于助人，耐心细致地回答各种问题
# - 知识截止到2024年7月
#
# 📱 **使用方式**：
# - 可以通过官方应用商店下载App使用
# - 也可以在网页端直接对话
#
# 我的知识范围比较广泛，无论是学习答疑、工作协助、创意写作，还是日常聊天，我都很乐意帮助你！有什么想了解的或需要帮助的吗？我会尽我所能为你提供支持！✨

# %% [markdown]
# &emsp;&emsp;如果可以正常收到`DeepSeek`模型的响应，则说明`DeepSeek`的`API`已经可以正常使用且网络连通性正常。

# %%
response
# Out:
# ChatCompletion(id='8756c206-b545-4d98-a1ea-136915a915ed', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='你好！我是DeepSeek，很高兴认识你！😊\n\n我是由深度求索公司创造的AI助手，致力于为大家提供热情、贴心的帮助。我有以下几个特点：\n\n🌟 **能力方面**：\n- 纯文本模型，擅长文字对话、分析和创作\n- 支持文件上传功能，可以处理图像、txt、pdf、ppt、word、excel等文件，并从中读取文字信息\n- 拥有128K的上下文长度，能够处理较长的对话和文档\n- 支持联网搜索功能（需要你在Web/App中手动开启）\n\n💝 **服务理念**：\n- 完全免费使用，没有任何收费计划\n- 乐于助人，耐心细致地回答各种问题\n- 知识截止到2024年7月\n\n📱 **使用方式**：\n- 可以通过官方应用商店下载App使用\n- 也可以在网页端直接对话\n\n我的知识范围比较广泛，无论是学习答疑、工作协助、创意写作，还是日常聊天，我都很乐意帮助你！有什么想了解的或需要帮助的吗？我会尽我所能为你提供支持！✨', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None))], created=1764657320, model='deepseek-chat', object='chat.completion', service_tier=None, system_fingerprint='fp_eaab8d114b_prod0820_fp8_kvcache', usage=CompletionUsage(completion_tokens=226, prompt_tokens=22, total_tokens=248, completion_tokens_details=None, prompt_tokens_details=PromptTokensDetails(audio_tokens=No
# ...

# %%
response.choices[0]
# Out:
# Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='你好！我是DeepSeek，很高兴认识你！😊\n\n我是由深度求索公司创造的AI助手，致力于为大家提供热情、贴心的帮助。我有以下几个特点：\n\n🌟 **能力方面**：\n- 纯文本模型，擅长文字对话、分析和创作\n- 支持文件上传功能，可以处理图像、txt、pdf、ppt、word、excel等文件，并从中读取文字信息\n- 拥有128K的上下文长度，能够处理较长的对话和文档\n- 支持联网搜索功能（需要你在Web/App中手动开启）\n\n💝 **服务理念**：\n- 完全免费使用，没有任何收费计划\n- 乐于助人，耐心细致地回答各种问题\n- 知识截止到2024年7月\n\n📱 **使用方式**：\n- 可以通过官方应用商店下载App使用\n- 也可以在网页端直接对话\n\n我的知识范围比较广泛，无论是学习答疑、工作协助、创意写作，还是日常聊天，我都很乐意帮助你！有什么想了解的或需要帮助的吗？我会尽我所能为你提供支持！✨', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None))

# %%
response.choices[0].message
# Out:
# ChatCompletionMessage(content='你好！我是DeepSeek，很高兴认识你！😊\n\n我是由深度求索公司创造的AI助手，致力于为大家提供热情、贴心的帮助。我有以下几个特点：\n\n🌟 **能力方面**：\n- 纯文本模型，擅长文字对话、分析和创作\n- 支持文件上传功能，可以处理图像、txt、pdf、ppt、word、excel等文件，并从中读取文字信息\n- 拥有128K的上下文长度，能够处理较长的对话和文档\n- 支持联网搜索功能（需要你在Web/App中手动开启）\n\n💝 **服务理念**：\n- 完全免费使用，没有任何收费计划\n- 乐于助人，耐心细致地回答各种问题\n- 知识截止到2024年7月\n\n📱 **使用方式**：\n- 可以通过官方应用商店下载App使用\n- 也可以在网页端直接对话\n\n我的知识范围比较广泛，无论是学习答疑、工作协助、创意写作，还是日常聊天，我都很乐意帮助你！有什么想了解的或需要帮助的吗？我会尽我所能为你提供支持！✨', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None)

# %%
response.choices[0].message.content
# Out:
# '你好！我是DeepSeek，很高兴认识你！😊\n\n我是由深度求索公司创造的AI助手，致力于为大家提供热情、贴心的帮助。我有以下几个特点：\n\n🌟 **能力方面**：\n- 纯文本模型，擅长文字对话、分析和创作\n- 支持文件上传功能，可以处理图像、txt、pdf、ppt、word、excel等文件，并从中读取文字信息\n- 拥有128K的上下文长度，能够处理较长的对话和文档\n- 支持联网搜索功能（需要你在Web/App中手动开启）\n\n💝 **服务理念**：\n- 完全免费使用，没有任何收费计划\n- 乐于助人，耐心细致地回答各种问题\n- 知识截止到2024年7月\n\n📱 **使用方式**：\n- 可以通过官方应用商店下载App使用\n- 也可以在网页端直接对话\n\n我的知识范围比较广泛，无论是学习答疑、工作协助、创意写作，还是日常聊天，我都很乐意帮助你！有什么想了解的或需要帮助的吗？我会尽我所能为你提供支持！✨'

# %% [markdown]
# - 推理模型调用流程

# %%
# 调用DeepSeek的API，生成回答
response_reasoner = client.chat.completions.create(
    model="deepseek-reasoner",
    messages=[
        {"role": "system", "content": "你是乐于助人的助手，请根据用户的问题给出回答"},
        {"role": "user", "content": "你好，请你介绍一下你自己。"},
    ],
)

# %%
response_reasoner
# Out:
# ChatCompletion(id='d62e8c7a-316c-4e5b-8dfc-f87484b7226e', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='你好！我是DeepSeek，一个由深度求索公司创造的AI助手！😊\n\n让我简单介绍一下自己：\n\n🌟 **基本信息**：\n- 我是DeepSeek最新版本的AI模型\n- 知识截止到2024年7月\n- 拥有128K的上下文处理能力\n\n🔧 **我能做什么**：\n- 回答各种问题，进行对话交流\n- 帮助处理文本、分析文档\n- 支持文件上传（图像、txt、pdf、ppt、word、excel等）\n- 可以进行联网搜索（需要你手动开启搜索功能）\n- 支持代码编写和调试\n- 协助创作、翻译、学习等任务\n\n💝 **我的特点**：\n- 完全免费使用\n- 热情细腻的交流风格\n- 乐于助人，尽力提供详细有用的回答\n\n📱 **使用方式**：\n- 可以通过网页版使用\n- 也可以下载官方App\n\n我的回复都是纯文本形式，虽然我不支持多模态识别，但我可以读取你上传的文件中的文字信息来帮助你。\n\n有什么想了解的或需要帮助的吗？我很乐意为你提供协助！✨', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, reasoning_content='嗯，用户让我介绍自己，这是个简单的开场问题。需要简洁清晰地说明身份和功能，让用户快速了解我能做什么。\n\n可以用友好问候开头，然后说明我是DeepSeek AI助手，由深度求索公司创造。要突出关键特性：免费、128K上下文、文件处理、联网搜索，顺便提醒使用限制。\n\n最后以开放性问题结束，引导用户继续对话。不需要太详细，保持亲切专业的语气就好。'))], created=1764657402, model='deepseek-reasoner', object='chat.completion', service_tier=None, sys
# ...

# %%
response_reasoner.choices[0].message
# Out:
# ChatCompletionMessage(content='你好！我是DeepSeek，一个由深度求索公司创造的AI助手！😊\n\n让我简单介绍一下自己：\n\n🌟 **基本信息**：\n- 我是DeepSeek最新版本的AI模型\n- 知识截止到2024年7月\n- 拥有128K的上下文处理能力\n\n🔧 **我能做什么**：\n- 回答各种问题，进行对话交流\n- 帮助处理文本、分析文档\n- 支持文件上传（图像、txt、pdf、ppt、word、excel等）\n- 可以进行联网搜索（需要你手动开启搜索功能）\n- 支持代码编写和调试\n- 协助创作、翻译、学习等任务\n\n💝 **我的特点**：\n- 完全免费使用\n- 热情细腻的交流风格\n- 乐于助人，尽力提供详细有用的回答\n\n📱 **使用方式**：\n- 可以通过网页版使用\n- 也可以下载官方App\n\n我的回复都是纯文本形式，虽然我不支持多模态识别，但我可以读取你上传的文件中的文字信息来帮助你。\n\n有什么想了解的或需要帮助的吗？我很乐意为你提供协助！✨', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, reasoning_content='嗯，用户让我介绍自己，这是个简单的开场问题。需要简洁清晰地说明身份和功能，让用户快速了解我能做什么。\n\n可以用友好问候开头，然后说明我是DeepSeek AI助手，由深度求索公司创造。要突出关键特性：免费、128K上下文、文件处理、联网搜索，顺便提醒使用限制。\n\n最后以开放性问题结束，引导用户继续对话。不需要太详细，保持亲切专业的语气就好。')

# %%
response_reasoner.choices[0].message.content
# Out:
# '你好！我是DeepSeek，一个由深度求索公司创造的AI助手！😊\n\n让我简单介绍一下自己：\n\n🌟 **基本信息**：\n- 我是DeepSeek最新版本的AI模型\n- 知识截止到2024年7月\n- 拥有128K的上下文处理能力\n\n🔧 **我能做什么**：\n- 回答各种问题，进行对话交流\n- 帮助处理文本、分析文档\n- 支持文件上传（图像、txt、pdf、ppt、word、excel等）\n- 可以进行联网搜索（需要你手动开启搜索功能）\n- 支持代码编写和调试\n- 协助创作、翻译、学习等任务\n\n💝 **我的特点**：\n- 完全免费使用\n- 热情细腻的交流风格\n- 乐于助人，尽力提供详细有用的回答\n\n📱 **使用方式**：\n- 可以通过网页版使用\n- 也可以下载官方App\n\n我的回复都是纯文本形式，虽然我不支持多模态识别，但我可以读取你上传的文件中的文字信息来帮助你。\n\n有什么想了解的或需要帮助的吗？我很乐意为你提供协助！✨'

# %%
response_reasoner.choices[0].message.reasoning_content
# Out:
# '嗯，用户让我介绍自己，这是个简单的开场问题。需要简洁清晰地说明身份和功能，让用户快速了解我能做什么。\n\n可以用友好问候开头，然后说明我是DeepSeek AI助手，由深度求索公司创造。要突出关键特性：免费、128K上下文、文件处理、联网搜索，顺便提醒使用限制。\n\n最后以开放性问题结束，引导用户继续对话。不需要太详细，保持亲切专业的语气就好。'

# %% [markdown]
# ### 2.DeepSeek-V3.2 Function calling调用流程

# %% [markdown]
# &emsp;&emsp;Function calling是大模型调用外部工具的关键技术，当我们要查询当前天气时，让大模型调用外部工具的function calling的过程就如图所示：
#
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/image-20250318202029130.png" alt="image-20250318202029130" style="zoom:35%;" />

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/202412191720637.png" alt="202412191720637" style="zoom:50%;" />

# %% [markdown]
# - 外部函数创建流程

# %%
import os
from dotenv import load_dotenv 
load_dotenv(override=True)

OPENWEATHER_API_KEY = os.getenv("OPENWEATHER_API_KEY")

# %%
import requests,json

# %%
def get_weather(loc):
    """
    查询即时天气函数
    :param loc: 必要参数，字符串类型，用于表示查询天气的具体城市名称，\
    注意，中国的城市需要用对应城市的英文名称代替，例如如果需要查询北京市天气，则loc参数需要输入'Beijing'；
    :return：OpenWeather API查询即时天气的结果，具体URL请求地址为：https://api.openweathermap.org/data/2.5/weather\
    返回结果对象类型为解析之后的JSON格式对象，并用字符串形式进行表示，其中包含了全部重要的天气信息
    """
    # Step 1.构建请求
    url = "https://api.openweathermap.org/data/2.5/weather"

    # Step 2.设置查询参数
    params = {
        "q": loc,               
        "appid": os.getenv("OPENWEATHER_API_KEY"),    # 输入API key
        "units": "metric",            # 使用摄氏度而不是华氏度
        "lang":"zh_cn"                # 输出语言为简体中文
    }

    # Step 3.发送GET请求
    response = requests.get(url, params=params)
    
    # Step 4.解析响应
    data = response.json()
    return json.dumps(data)

# %%
get_weather("Beijing")
# Out:
# '{"coord": {"lon": 116.3972, "lat": 39.9075}, "weather": [{"id": 800, "main": "Clear", "description": "\\u6674", "icon": "01d"}], "base": "stations", "main": {"temp": -1.06, "feels_like": -6.04, "temp_min": -1.06, "temp_max": -1.06, "pressure": 1031, "humidity": 10, "sea_level": 1031, "grnd_level": 1025}, "visibility": 10000, "wind": {"speed": 4.67, "deg": 317, "gust": 10.29}, "clouds": {"all": 0}, "dt": 1764657342, "sys": {"type": 1, "id": 9609, "country": "CN", "sunrise": 1764631062, "sunset": 1764665409}, "timezone": 28800, "id": 1816670, "name": "Beijing", "cod": 200}'

# %%
tools = [
    {
        "type": "function",
        "function":{
            'name': 'get_weather',
            'description': '查询即时天气函数，根据输入的城市名称，查询对应城市的实时天气，一次只能输入一个城市名称',
            'parameters': {
                'type': 'object',
                'properties': {
                    'loc': {
                        'description': "城市名称，注意，中国的城市需要用对应城市的英文名称代替，例如如果需要查询北京市天气，则loc参数需要输入'Beijing'",
                        'type': 'string'
                    }
                },
                'required': ['loc']
            }
        }
    }
]

# %% [markdown]
# - Function calling执行流程

# %%
messages=[
    {"role": "user", "content": "请问北京今天天气如何？"}
]

# %%
chat_response = client.chat.completions.create(
    model="deepseek-chat",  
    messages=messages,
    tools=tools,
)

# %%
chat_response
# Out:
# ChatCompletion(id='547b486b-130c-48cc-9610-2e98b1c7c26d', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content='我来帮您查询北京今天的天气情况。', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_00_KYFhVE6ASFoaJb8W2zLZgYQJ', function=Function(arguments='{"loc": "Beijing"}', name='get_weather'), type='function', index=0)]))], created=1764659290, model='deepseek-chat', object='chat.completion', service_tier=None, system_fingerprint='fp_eaab8d114b_prod0820_fp8_kvcache', usage=CompletionUsage(completion_tokens=52, prompt_tokens=353, total_tokens=405, completion_tokens_details=None, prompt_tokens_details=PromptTokensDetails(audio_tokens=None, cached_tokens=320), prompt_cache_hit_tokens=320, prompt_cache_miss_tokens=33))

# %%
chat_response.choices[0]
# Out:
# Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content='我来帮您查询北京今天的天气情况。', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_00_KYFhVE6ASFoaJb8W2zLZgYQJ', function=Function(arguments='{"loc": "Beijing"}', name='get_weather'), type='function', index=0)]))

# %%
chat_response.choices[0].finish_reason
# Out:
# 'tool_calls'

# %%
chat_response.choices[0].message.content
# Out:
# '我来帮您查询北京今天的天气情况。'

# %%
chat_response.choices[0].message.tool_calls
# Out:
# [ChatCompletionMessageFunctionToolCall(id='call_00_KYFhVE6ASFoaJb8W2zLZgYQJ', function=Function(arguments='{"loc": "Beijing"}', name='get_weather'), type='function', index=0)]

# %%
reasoner_response = client.chat.completions.create(
    model="deepseek-reasoner",  
    messages=messages,
    tools=tools,
)

# %%
reasoner_response
# Out:
# ChatCompletion(id='d03bff17-261b-4660-95b2-4a50a985eed1', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content='', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_00_ixFHiedGONNUL796DOE549PM', function=Function(arguments='{"loc": "Beijing"}', name='get_weather'), type='function', index=0)], reasoning_content='用户想了解北京今天的天气情况。我需要使用get_weather函数来查询北京的天气。根据函数描述，城市名称需要用英文表示，北京对应的英文是"Beijing"。所以，我应该调用get_weather函数，参数loc设为"Beijing"。现在就来执行这个操作。'))], created=1764659360, model='deepseek-reasoner', object='chat.completion', service_tier=None, system_fingerprint='fp_eaab8d114b_prod0820_fp8_kvcache', usage=CompletionUsage(completion_tokens=102, prompt_tokens=353, total_tokens=455, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=None, reasoning_tokens=57, rejected_prediction_tokens=None), prompt_tokens_deta
# ...

# %%
reasoner_response.choices[0]
# Out:
# Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content='', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_00_ixFHiedGONNUL796DOE549PM', function=Function(arguments='{"loc": "Beijing"}', name='get_weather'), type='function', index=0)], reasoning_content='用户想了解北京今天的天气情况。我需要使用get_weather函数来查询北京的天气。根据函数描述，城市名称需要用英文表示，北京对应的英文是"Beijing"。所以，我应该调用get_weather函数，参数loc设为"Beijing"。现在就来执行这个操作。'))

# %%
reasoner_response.choices[0].finish_reason
# Out:
# 'tool_calls'

# %%
reasoner_response.choices[0].message.reasoning_content
# Out:
# '用户想了解北京今天的天气情况。我需要使用get_weather函数来查询北京的天气。根据函数描述，城市名称需要用英文表示，北京对应的英文是"Beijing"。所以，我应该调用get_weather函数，参数loc设为"Beijing"。现在就来执行这个操作。'

# %%
reasoner_response.choices[0].message.tool_calls
# Out:
# [ChatCompletionMessageFunctionToolCall(id='call_00_ixFHiedGONNUL796DOE549PM', function=Function(arguments='{"loc": "Beijing"}', name='get_weather'), type='function', index=0)]

# %%
available_functions = {
            "get_weather": get_weather,
        }

# %%
function_call_messages = reasoner_response.choices[0].message.tool_calls
function_call_messages
# Out:
# [ChatCompletionMessageFunctionToolCall(id='call_00_ixFHiedGONNUL796DOE549PM', function=Function(arguments='{"loc": "Beijing"}', name='get_weather'), type='function', index=0)]

# %%
len(function_call_messages)
# Out:
# 1

# %%
function_call_messages[0]
# Out:
# ChatCompletionMessageFunctionToolCall(id='call_00_ixFHiedGONNUL796DOE549PM', function=Function(arguments='{"loc": "Beijing"}', name='get_weather'), type='function', index=0)

# %%
tool_call = function_call_messages[0]

# %%
tool_name = tool_call.function.name
tool_args = json.loads(tool_call.function.arguments)

# %%
tool_name,tool_args
# Out:
# ('get_weather', {'loc': 'Beijing'})

# %%
fuction_to_call = available_functions[tool_name]
fuction_to_call
# Out:
# <function __main__.get_weather(loc)>

# %%
function_response = fuction_to_call(**tool_args)

# %%
function_response
# Out:
# '{"coord": {"lon": 116.3972, "lat": 39.9075}, "weather": [{"id": 800, "main": "Clear", "description": "\\u6674", "icon": "01d"}], "base": "stations", "main": {"temp": -1.06, "feels_like": -6.04, "temp_min": -1.06, "temp_max": -1.06, "pressure": 1030, "humidity": 9, "sea_level": 1030, "grnd_level": 1025}, "visibility": 10000, "wind": {"speed": 4.67, "deg": 317, "gust": 10.29}, "clouds": {"all": 0}, "dt": 1764659286, "sys": {"type": 1, "id": 9609, "country": "CN", "sunrise": 1764631062, "sunset": 1764665409}, "timezone": 28800, "id": 1816670, "name": "Beijing", "cod": 200}'

# %%
# function call message
reasoner_response.choices[0].message.model_dump()
# Out:
# {'content': '',
#  'refusal': None,
#  'role': 'assistant',
#  'annotations': None,
#  'audio': None,
#  'function_call': None,
#  'tool_calls': [{'id': 'call_00_ixFHiedGONNUL796DOE549PM',
#    'function': {'arguments': '{"loc": "Beijing"}', 'name': 'get_weather'},
#    'type': 'function',
#    'index': 0}],
#  'reasoning_content': '用户想了解北京今天的天气情况。我需要使用get_weather函数来查询北京的天气。根据函数描述，城市名称需要用英文表示，北京对应的英文是"Beijing"。所以，我应该调用get_weather函数，参数loc设为"Beijing"。现在就来执行这个操作。'}

# %%
# function response message
{
    "role": "tool",
    "content": function_response,
    "tool_call_id": tool_call.id,
}
# Out:
# {'role': 'tool',
#  'content': '{"coord": {"lon": 116.3972, "lat": 39.9075}, "weather": [{"id": 800, "main": "Clear", "description": "\\u6674", "icon": "01d"}], "base": "stations", "main": {"temp": -1.06, "feels_like": -6.04, "temp_min": -1.06, "temp_max": -1.06, "pressure": 1030, "humidity": 9, "sea_level": 1030, "grnd_level": 1025}, "visibility": 10000, "wind": {"speed": 4.67, "deg": 317, "gust": 10.29}, "clouds": {"all": 0}, "dt": 1764659286, "sys": {"type": 1, "id": 9609, "country": "CN", "sunrise": 1764631062, "sunset": 1764665409}, "timezone": 28800, "id": 1816670, "name": "Beijing", "cod": 200}',
#  'tool_call_id': 'call_00_ixFHiedGONNUL796DOE549PM'}

# %%
messages
# Out:
# [{'role': 'user', 'content': '请问北京今天天气如何？'}]

# %%
messages.append(reasoner_response.choices[0].message.model_dump())
messages.append(
    {
        "role": "tool",
        "content": function_response,
        "tool_call_id": tool_call.id,
    }
)

# %%
messages
# Out:
# [{'role': 'user', 'content': '请问北京今天天气如何？'},
#  {'content': '',
#   'refusal': None,
#   'role': 'assistant',
#   'annotations': None,
#   'audio': None,
#   'function_call': None,
#   'tool_calls': [{'id': 'call_00_ixFHiedGONNUL796DOE549PM',
#     'function': {'arguments': '{"loc": "Beijing"}', 'name': 'get_weather'},
#     'type': 'function',
#     'index': 0}],
#   'reasoning_content': '用户想了解北京今天的天气情况。我需要使用get_weather函数来查询北京的天气。根据函数描述，城市名称需要用英文表示，北京对应的英文是"Beijing"。所以，我应该调用get_weather函数，参数loc设为"Beijing"。现在就来执行这个操作。'},
#  {'role': 'tool',
# ...

# %%
# 第二次响应
response = client.chat.completions.create(
    model="deepseek-reasoner",  
    messages=messages,
    tools=tools,
)

# %%
response
# Out:
# ChatCompletion(id='2973e5f5-deba-4733-a032-d65ba1326b74', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='根据查询结果，北京今天天气情况如下：\n\n**天气状况**：☀️ 晴朗（Clear）\n**当前温度**：-1.06°C\n**体感温度**：-6.04°C（由于风寒效应，实际体感较冷）\n**湿度**：9%（非常干燥）\n**气压**：1030 hPa\n**风速**：4.67米/秒，西北风（约317°）\n**能见度**：10公里\n**云量**：0%（无云）\n\n今天北京天气非常晴朗，但温度较低，体感温度接近-6°C，建议外出时注意保暖，做好防寒措施。空气较为干燥，也请注意保湿。', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, reasoning_content='我已经收到了北京的天气数据。现在需要将这些信息以中文形式整理并回复给用户。\n\n数据解读：\n- 天气情况：Clear（晴天），描述为“晴”\n- 温度：-1.06°C（实际温度），体感温度-6.04°C\n- 气压：1030 hPa\n- 湿度：9%\n- 风速：4.67 m/s，风向317度（大约西北风）\n- 能见度：10000米\n- 云量：0%（无云）\n\n我需要用中文组织回复，告知用户北京今天的天气情况。回复中应包括温度、天气状况、体感温度、湿度和风速等关键信息。\n\n现在开始组织回复。'))], created=1764659549, model='deepseek-reasoner', object='chat.completion', service_tier=None, system_fingerprint='fp_eaab8d114b_prod0820_fp8_kvcache', usage=CompletionUsage(completion_tokens=300, prompt_tokens=72
# ...

# %%
response.choices[0].message
# Out:
# ChatCompletionMessage(content='根据查询结果，北京今天天气情况如下：\n\n**天气状况**：☀️ 晴朗（Clear）\n**当前温度**：-1.06°C\n**体感温度**：-6.04°C（由于风寒效应，实际体感较冷）\n**湿度**：9%（非常干燥）\n**气压**：1030 hPa\n**风速**：4.67米/秒，西北风（约317°）\n**能见度**：10公里\n**云量**：0%（无云）\n\n今天北京天气非常晴朗，但温度较低，体感温度接近-6°C，建议外出时注意保暖，做好防寒措施。空气较为干燥，也请注意保湿。', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, reasoning_content='我已经收到了北京的天气数据。现在需要将这些信息以中文形式整理并回复给用户。\n\n数据解读：\n- 天气情况：Clear（晴天），描述为“晴”\n- 温度：-1.06°C（实际温度），体感温度-6.04°C\n- 气压：1030 hPa\n- 湿度：9%\n- 风速：4.67 m/s，风向317度（大约西北风）\n- 能见度：10000米\n- 云量：0%（无云）\n\n我需要用中文组织回复，告知用户北京今天的天气情况。回复中应包括温度、天气状况、体感温度、湿度和风速等关键信息。\n\n现在开始组织回复。')

# %%
response.choices[0].finish_reason
# Out:
# 'stop'

# %% [markdown]
# - 基于DeepSeek-V3.2的多工具调用流程

# %%
messages2=[
    {"role": "user", "content": "请问北京和杭州今天天气如何？"}
]

# %%
response2 = client.chat.completions.create(
    model="deepseek-reasoner",  
    messages=messages2,
    tools=tools,
)

# %%
response2.choices[0].message
# Out:
# ChatCompletionMessage(content='', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_00_sBTH2q5djhNLlQRBpY1AoWGN', function=Function(arguments='{"loc": "Beijing"}', name='get_weather'), type='function', index=0)], reasoning_content='用户想了解北京和杭州的天气情况。我需要使用天气查询工具来获取这两个城市的天气信息。根据工具说明，一次只能查询一个城市，所以我需要分别查询北京和杭州。\n\n首先，查询北京的天气。使用工具get_weather，参数loc设置为"Beijing"。')

# %%
response2.choices[0].message.tool_calls
# Out:
# [ChatCompletionMessageFunctionToolCall(id='call_00_sBTH2q5djhNLlQRBpY1AoWGN', function=Function(arguments='{"loc": "Beijing"}', name='get_weather'), type='function', index=0)]

# %%
function_call_messages = response2.choices[0].message.tool_calls
function_call_messages
# Out:
# [ChatCompletionMessageFunctionToolCall(id='call_00_sBTH2q5djhNLlQRBpY1AoWGN', function=Function(arguments='{"loc": "Beijing"}', name='get_weather'), type='function', index=0)]

# %%
response2.choices[0].message.model_dump()
# Out:
# {'content': '',
#  'refusal': None,
#  'role': 'assistant',
#  'annotations': None,
#  'audio': None,
#  'function_call': None,
#  'tool_calls': [{'id': 'call_00_sBTH2q5djhNLlQRBpY1AoWGN',
#    'function': {'arguments': '{"loc": "Beijing"}', 'name': 'get_weather'},
#    'type': 'function',
#    'index': 0}],
#  'reasoning_content': '用户想了解北京和杭州的天气情况。我需要使用天气查询工具来获取这两个城市的天气信息。根据工具说明，一次只能查询一个城市，所以我需要分别查询北京和杭州。\n\n首先，查询北京的天气。使用工具get_weather，参数loc设置为"Beijing"。'}

# %% [markdown]
# 创建create_function_response_messages函数，一次性构建完整回复：

# %%
def create_function_response_messages(messages, response):
    function_call_messages = response.choices[0].message.tool_calls
    messages.append(response.choices[0].message.model_dump())
    for function_call_message in function_call_messages:
        tool_name = function_call_message.function.name
        tool_args = json.loads(function_call_message.function.arguments)
        
        # 运行外部函数
        fuction_to_call = available_functions[tool_name]
        try:
            function_response = fuction_to_call(**tool_args)
        except Exception as e:
            function_response = "函数运行报错如下:" + str(e)

        # 拼接消息队列
        messages.append(
            {
                "role": "tool",
                "content": function_response,
                "tool_call_id": function_call_message.id,
            }
        )
    return messages

# %%
messages2=[
    {"role": "user", "content": "请问北京和杭州今天天气如何？"}
]
messages2
# Out:
# [{'role': 'user', 'content': '请问北京和杭州今天天气如何？'}]

# %%
response2
# Out:
# ChatCompletion(id='b1b4c34e-0eb5-4ef0-a414-4f9ccad5ee5f', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content='', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_00_sBTH2q5djhNLlQRBpY1AoWGN', function=Function(arguments='{"loc": "Beijing"}', name='get_weather'), type='function', index=0)], reasoning_content='用户想了解北京和杭州的天气情况。我需要使用天气查询工具来获取这两个城市的天气信息。根据工具说明，一次只能查询一个城市，所以我需要分别查询北京和杭州。\n\n首先，查询北京的天气。使用工具get_weather，参数loc设置为"Beijing"。'))], created=1764659712, model='deepseek-reasoner', object='chat.completion', service_tier=None, system_fingerprint='fp_eaab8d114b_prod0820_fp8_kvcache', usage=CompletionUsage(completion_tokens=103, prompt_tokens=355, total_tokens=458, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=None, reasoning_tokens=58, rejected_prediction_tokens=None), prompt_tokens_details=Pr
# ...

# %%
messages2 = create_function_response_messages(messages2, response2)

# %%
messages2
# Out:
# [{'role': 'user', 'content': '请问北京和杭州今天天气如何？'},
#  {'content': '',
#   'refusal': None,
#   'role': 'assistant',
#   'annotations': None,
#   'audio': None,
#   'function_call': None,
#   'tool_calls': [{'id': 'call_00_sBTH2q5djhNLlQRBpY1AoWGN',
#     'function': {'arguments': '{"loc": "Beijing"}', 'name': 'get_weather'},
#     'type': 'function',
#     'index': 0}],
#   'reasoning_content': '用户想了解北京和杭州的天气情况。我需要使用天气查询工具来获取这两个城市的天气信息。根据工具说明，一次只能查询一个城市，所以我需要分别查询北京和杭州。\n\n首先，查询北京的天气。使用工具get_weather，参数loc设置为"Beijing"。'},
#  {'role': 'tool',
# ...

# %%
# 第二次响应
response = client.chat.completions.create(
    model="deepseek-reasoner",  
    messages=messages2,
    tools=tools,
)

# %%
response.choices[0].message
# Out:
# ChatCompletionMessage(content='', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_00_VXdCv2M2Q8nSHisWCTCnbjzz', function=Function(arguments='{"loc": "Hangzhou"}', name='get_weather'), type='function', index=0)], reasoning_content='北京天气查询结果返回了。数据显示天气晴朗（Clear），温度-1.06°C，体感温度-6.04°C，湿度10%，风速4.67米/秒，能见度10000米。现在需要查询杭州的天气。使用工具get_weather，参数loc设置为"Hangzhou"。')

# %%
messages3 = create_function_response_messages(messages2, response)

# %%
messages3
# Out:
# [{'role': 'user', 'content': '请问北京和杭州今天天气如何？'},
#  {'content': '',
#   'refusal': None,
#   'role': 'assistant',
#   'annotations': None,
#   'audio': None,
#   'function_call': None,
#   'tool_calls': [{'id': 'call_00_sBTH2q5djhNLlQRBpY1AoWGN',
#     'function': {'arguments': '{"loc": "Beijing"}', 'name': 'get_weather'},
#     'type': 'function',
#     'index': 0}],
#   'reasoning_content': '用户想了解北京和杭州的天气情况。我需要使用天气查询工具来获取这两个城市的天气信息。根据工具说明，一次只能查询一个城市，所以我需要分别查询北京和杭州。\n\n首先，查询北京的天气。使用工具get_weather，参数loc设置为"Beijing"。'},
#  {'role': 'tool',
# ...

# %%
# 第三次响应
response = client.chat.completions.create(
    model="deepseek-reasoner",  
    messages=messages3,
    tools=tools,
)

# %%
response.choices[0].message
# Out:
# ChatCompletionMessage(content='根据实时天气数据，北京和杭州今天的天气情况如下：\n\n## 北京\n- **天气状况**：晴朗 ☀️\n- **当前温度**：-1.1°C\n- **体感温度**：-6.0°C（风寒效应明显）\n- **湿度**：10%（非常干燥）\n- **风速**：4.7 m/s（西北风，阵风10.3 m/s）\n- **能见度**：10公里\n- **气压**：1031 hPa\n\n## 杭州\n- **天气状况**：阴天，多云 ☁️\n- **当前温度**：16.0°C\n- **体感温度**：15.3°C\n- **湿度**：64%\n- **风速**：4.3 m/s（北风，阵风5.8 m/s）\n- **能见度**：10公里\n- **气压**：1021 hPa\n\n**对比说明**：两个城市温差较大，北京处于严寒干燥的晴朗天气，而杭州则是温和湿润的多云天气。北京气温低于冰点，体感温度更低，需要注意防寒保暖；杭州温度适中，但湿度较高，体感较为舒适。', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, reasoning_content='杭州的天气数据也返回了：多云（Clouds），温度15.95°C，体感温度15.27°C，湿度64%，风速4.26米/秒，能见度10000米。\n\n现在我需要把这些信息组织成对用户友好的回答。要包含两个城市的天气情况，比如天气状况、温度、体感温度、湿度和风速等。同时，可以提一下这是实时数据。\n\n接下来，用中文来回答，因为用户是用中文提问的。先总结一下北京和杭州的天气情况。\n\n北京：晴朗，气温-1.06°C，体感温度-6.04°C，湿度10%，风速4.67米/秒。\n杭州：阴天，多云，气温15.95°C，体感温度15.27°C，湿度64%，风速4.26米/秒。\n\n可以指出两个城市温差较大，北京寒冷，杭州相对温和。\n\n现在开始撰写回答。')

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/image-20251202151950194.png" alt="image-20251202151950194" style="zoom:50%;" />

# %%
messages3 + [response.choices[0].message.model_dump()]
# Out:
# [{'role': 'user', 'content': '请问北京和杭州今天天气如何？'},
#  {'content': '',
#   'refusal': None,
#   'role': 'assistant',
#   'annotations': None,
#   'audio': None,
#   'function_call': None,
#   'tool_calls': [{'id': 'call_00_sBTH2q5djhNLlQRBpY1AoWGN',
#     'function': {'arguments': '{"loc": "Beijing"}', 'name': 'get_weather'},
#     'type': 'function',
#     'index': 0}],
#   'reasoning_content': '用户想了解北京和杭州的天气情况。我需要使用天气查询工具来获取这两个城市的天气信息。根据工具说明，一次只能查询一个城市，所以我需要分别查询北京和杭州。\n\n首先，查询北京的天气。使用工具get_weather，参数loc设置为"Beijing"。'},
#  {'role': 'tool',
# ...

# %% [markdown]
# ## 三、LangChain中调用DeepSeek-V3.2模型完整流程

# %%
import langchain

# %%
langchain.__version__
# Out:
# '1.1.0'

# %% [markdown]
# ### 1. DeepSeek接入LangChain流程

# %% [markdown]
# &emsp;&emsp;接下来我们要考虑的是，对于这样一个`DeepSeek`官方的`API`，如何接入到`LangChain`中呢？其实非常简单，我们只需要使用`LangChain`中的一个`DeepSeek`组件即可向像述代码一样，直接使用相同的`DeepSeek API KEY`与大模型进行交互。因此，我们首先需要安装`LangChain`的`DeepSeek`组件，安装命令如下：

# %%
# ! pip install langchain-deepseek

# %% [markdown]
# &emsp;&emsp;安装好`LangChain`集成`DeepSeek`模型的依赖包后，需要ChatDeepSeek函数来初始化大模型，代码如下：

# %%
from langchain_deepseek import ChatDeepSeek

model = ChatDeepSeek(model="deepseek-chat")

# %% [markdown]
# &emsp;&emsp;其中`model`用来指定要使用的模型名称，而`model_provider`用来指定模型提供者，当写入`deepseek`时，会自动加载`langchain-deepseek`的依赖包，并使用在`model`中指定的模型名称用来进行交互。

# %%
question = "你好，请你介绍一下你自己。"

result = model.invoke(question)

# %%
print(result.content)
# Out:
# 你好！我是DeepSeek，很高兴认识你！😊
#
# 我是由深度求索公司创造的AI助手，致力于为大家提供热情、细腻的帮助服务。让我简单介绍一下自己的特点：
#
# **我的能力：**
# - 📝 纯文本对话，可以回答各种问题、协助写作、分析问题等
# - 📁 支持文件上传功能，可以处理图像、txt、pdf、ppt、word、excel等文件，并读取其中的文字信息
# - 🌐 支持联网搜索（需要你在Web/App中手动开启）
# - 💬 拥有128K的上下文长度，能记住我们较长的对话内容
#
# **我的特点：**
# - 🆓 完全免费使用，没有收费计划
# - 📱 可通过官方应用商店下载App使用
# - 🔄 知识更新到2024年7月
# - 🤝 回复风格热情友好，力求细致周到
#
# **我的局限：**
# - 我是纯文本模型，不支持多模态识别
# - 没有语音功能
# - 需要手动开启联网搜索
#
# 我的使命就是尽我所能帮助你解决问题、提供信息支持、协助思考决策等。无论你想聊天、学习、工作还是需要创意灵感，我都很乐意陪伴你一起探索！
#
# 有什么特别想了解的，或者需要我帮助的吗？我会用心为你解答！✨

# %%
result
# Out:
# AIMessage(content='你好！我是DeepSeek，很高兴认识你！😊\n\n我是由深度求索公司创造的AI助手，致力于为大家提供热情、细腻的帮助服务。让我简单介绍一下自己的特点：\n\n**我的能力：**\n- 📝 纯文本对话，可以回答各种问题、协助写作、分析问题等\n- 📁 支持文件上传功能，可以处理图像、txt、pdf、ppt、word、excel等文件，并读取其中的文字信息\n- 🌐 支持联网搜索（需要你在Web/App中手动开启）\n- 💬 拥有128K的上下文长度，能记住我们较长的对话内容\n\n**我的特点：**\n- 🆓 完全免费使用，没有收费计划\n- 📱 可通过官方应用商店下载App使用\n- 🔄 知识更新到2024年7月\n- 🤝 回复风格热情友好，力求细致周到\n\n**我的局限：**\n- 我是纯文本模型，不支持多模态识别\n- 没有语音功能\n- 需要手动开启联网搜索\n\n我的使命就是尽我所能帮助你解决问题、提供信息支持、协助思考决策等。无论你想聊天、学习、工作还是需要创意灵感，我都很乐意陪伴你一起探索！\n\n有什么特别想了解的，或者需要我帮助的吗？我会用心为你解答！✨', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 274, 'prompt_tokens': 10, 'total_tokens': 284, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 10}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_eaab8d114b_prod0820_fp8_kvcache', 'id': '402d02c2-d0aa-4e73-bc16-a04b6737ca1c', 'finish_
# ...

# %%
model = ChatDeepSeek(model="deepseek-reasoner")

result = model.invoke(question)
print(result.content)
# Out:
# 你好！我是DeepSeek，由深度求索公司创造的AI助手，很高兴认识你！😊
#
# 让我简单介绍一下自己：
#
# **基本信息：**
# - 我是一个纯文本AI模型，专注于理解和生成自然语言
# - 知识截止到2024年7月，拥有128K的上下文处理能力
# - 完全免费使用，没有收费计划
#
# **我的能力：**
# - 回答各种问题，进行深度对话和讨论
# - 处理文档：支持上传图像、txt、pdf、ppt、word、excel文件并读取其中的文字信息
# - 支持联网搜索（需要手动开启）
# - 协助写作、分析、学习、创作等多种任务
#
# **我的特点：**
# - 热情细腻的交流风格，喜欢用心帮助每位用户
# - 诚实坦率，遇到不清楚的问题会如实告知
# - 力求提供准确、有用的信息和建议
#
# **使用方式：**
# - 可以通过网页版使用
# - 也可以通过官方应用商店下载App
#
# 我很乐意成为你的学习伙伴、创作助手或聊天朋友！无论是工作学习中的问题，还是日常生活中的疑惑，或者只是想聊聊天，我都在这里准备帮助你。
#
# 有什么想了解或需要帮助的吗？我很期待和你的交流！✨

# %%
result
# Out:
# AIMessage(content='你好！我是DeepSeek，由深度求索公司创造的AI助手，很高兴认识你！😊\n\n让我简单介绍一下自己：\n\n**基本信息：**\n- 我是一个纯文本AI模型，专注于理解和生成自然语言\n- 知识截止到2024年7月，拥有128K的上下文处理能力\n- 完全免费使用，没有收费计划\n\n**我的能力：**\n- 回答各种问题，进行深度对话和讨论\n- 处理文档：支持上传图像、txt、pdf、ppt、word、excel文件并读取其中的文字信息\n- 支持联网搜索（需要手动开启）\n- 协助写作、分析、学习、创作等多种任务\n\n**我的特点：**\n- 热情细腻的交流风格，喜欢用心帮助每位用户\n- 诚实坦率，遇到不清楚的问题会如实告知\n- 力求提供准确、有用的信息和建议\n\n**使用方式：**\n- 可以通过网页版使用\n- 也可以通过官方应用商店下载App\n\n我很乐意成为你的学习伙伴、创作助手或聊天朋友！无论是工作学习中的问题，还是日常生活中的疑惑，或者只是想聊聊天，我都在这里准备帮助你。\n\n有什么想了解或需要帮助的吗？我很期待和你的交流！✨', additional_kwargs={'refusal': None, 'reasoning_content': '哦，用户让我做个自我介绍，这是个很基础的请求。需要简洁清晰地说清楚身份、功能和特点，避免过度展开。\n\n想到了可以用公司背景和核心能力作为开头，这样能快速建立信任感。接着说明文本交互的属性和知识截止时间，避免用户产生不切实际的期待。\n\n需要列举一些典型的使用场景，帮助用户理解我能做什么。最后用友好的语气收尾，保持开放态度邀请提问。整体保持热情但不过度活泼，符合一贯的助手定位。'}, response_metadata={'token_usage': {'completion_tokens': 357, 'prompt_tokens': 10, 'total_tokens': 367, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 102, 'rejected_predictio
# ...

# %%
result.additional_kwargs
# Out:
# {'refusal': None,
#  'reasoning_content': '哦，用户让我做个自我介绍，这是个很基础的请求。需要简洁清晰地说清楚身份、功能和特点，避免过度展开。\n\n想到了可以用公司背景和核心能力作为开头，这样能快速建立信任感。接着说明文本交互的属性和知识截止时间，避免用户产生不切实际的期待。\n\n需要列举一些典型的使用场景，帮助用户理解我能做什么。最后用友好的语气收尾，保持开放态度邀请提问。整体保持热情但不过度活泼，符合一贯的助手定位。'}

# %%
result.additional_kwargs['reasoning_content']
# Out:
# '哦，用户让我做个自我介绍，这是个很基础的请求。需要简洁清晰地说清楚身份、功能和特点，避免过度展开。\n\n想到了可以用公司背景和核心能力作为开头，这样能快速建立信任感。接着说明文本交互的属性和知识截止时间，避免用户产生不切实际的期待。\n\n需要列举一些典型的使用场景，帮助用户理解我能做什么。最后用友好的语气收尾，保持开放态度邀请提问。整体保持热情但不过度活泼，符合一贯的助手定位。'

# %% [markdown]
# ### 2. LangChain 1.1创建Agent基础流程

# %%
from langchain.tools import tool

# %%
@tool
def get_weather(loc):
    """
    查询即时天气函数
    :param loc: 必要参数，字符串类型，用于表示查询天气的具体城市名称，\
    注意，中国的城市需要用对应城市的英文名称代替，例如如果需要查询北京市天气，则loc参数需要输入'Beijing'；
    :return：OpenWeather API查询即时天气的结果，具体URL请求地址为：https://api.openweathermap.org/data/2.5/weather\
    返回结果对象类型为解析之后的JSON格式对象，并用字符串形式进行表示，其中包含了全部重要的天气信息
    """
    # Step 1.构建请求
    url = "https://api.openweathermap.org/data/2.5/weather"

    # Step 2.设置查询参数
    params = {
        "q": loc,               
        "appid": os.getenv("OPENWEATHER_API_KEY"),    # 输入API key
        "units": "metric",            # 使用摄氏度而不是华氏度
        "lang":"zh_cn"                # 输出语言为简体中文
    }

    # Step 3.发送GET请求
    response = requests.get(url, params=params)
    
    # Step 4.解析响应
    data = response.json()
    return json.dumps(data)

# %%
print(get_weather.name)
print(get_weather.description)
print(get_weather.args)
# Out:
# get_weather
# 查询即时天气函数
# :param loc: 必要参数，字符串类型，用于表示查询天气的具体城市名称，    注意，中国的城市需要用对应城市的英文名称代替，例如如果需要查询北京市天气，则loc参数需要输入'Beijing'；
# :return：OpenWeather API查询即时天气的结果，具体URL请求地址为：https://api.openweathermap.org/data/2.5/weather    返回结果对象类型为解析之后的JSON格式对象，并用字符串形式进行表示，其中包含了全部重要的天气信息
# {'loc': {'title': 'Loc'}}

# %% [markdown]
# 然后即可直接带入到create_agent中，创建一个简易的天气查询Agent：

# %%
# 1.导入相关库
from langchain.agents import create_agent
from langchain_deepseek import ChatDeepSeek
from langchain_community.tools.tavily_search import TavilySearchResults

# 2.导入模型
model = ChatDeepSeek(model="deepseek-chat")

# 3.创建Agent
agent = create_agent(
    model=model,
    tools=[get_weather],
    system_prompt="你是一名多才多艺的智能助手，可以调用工具帮助用户解决问题。"
)

# %%
# 4.运行Agent获得结果
result = agent.invoke(
    {"messages": [{"role": "user", "content": "请问北京今天天气如何？"}]}
)

# %%
result['messages'][-1].content
# Out:
# '根据查询结果，北京今天的天气情况如下：\n\n**天气状况：** 晴天 ☀️\n**温度：** -1.06°C\n**体感温度：** -5.5°C\n**最低/最高温度：** -1.06°C（当前温度）\n**湿度：** 9%（非常干燥）\n**气压：** 1030 hPa\n**风速：** 3.88米/秒（约14公里/小时）\n**风向：** 306度（西北风）\n**能见度：** 10公里（很好）\n**云量：** 0%（无云）\n\n**总结：** 今天北京天气非常晴朗，但气温较低，只有零下1度左右，体感温度更低（零下5.5度）。空气非常干燥，风力适中。建议您外出时注意保暖，穿戴厚实的衣物，特别是要注意防风保暖。'

# %% [markdown]
# 而同样，这也是一个典型的Fucntion calling流程。

# %%
len(result['messages'])
# Out:
# 4

# %%
result['messages']
# Out:
# [HumanMessage(content='请问北京今天天气如何？', additional_kwargs={}, response_metadata={}, id='fb7c0fac-e711-42ce-84a7-50a26d6082d8'),
# ...

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/image-20251028154837987.png" alt="image-20251028154837987" style="zoom:50%;" />

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/image-20251028171815049.png" alt="image-20251028171815049" style="zoom:50%;" />

# %% [markdown]
# 例如：

# %%
result = agent.invoke(
    {"messages": [{"role": "user", "content": "请问今天杭州和南昌哪里更冷？"}]}
)

# %%
result['messages'][-1].content
# Out:
# '根据查询结果，我来为您比较一下杭州和南昌的天气情况：\n\n**杭州天气：**\n- 温度：14.95°C\n- 体感温度：14.12°C\n- 天气状况：阴，多云\n- 湿度：62%\n- 风速：3.15 m/s\n\n**南昌天气：**\n- 温度：18.2°C\n- 体感温度：17.38°C\n- 天气状况：阴，多云\n- 湿度：50%\n- 风速：6.04 m/s\n\n**比较结果：**\n**杭州比南昌更冷**。杭州的温度为14.95°C，而南昌的温度为18.2°C，杭州比南昌低约3.25°C。从体感温度来看，杭州的14.12°C也比南昌的17.38°C低约3.26°C。\n\n另外，杭州的湿度更高（62% vs 50%），而南昌的风速更大（6.04 m/s vs 3.15 m/s），但总体上杭州的温度明显更低，所以今天杭州比南昌更冷。'

# %% [markdown]
# 此时Agent进行了多工具的并发调用。

# %%
result
# Out:
# {'messages': [HumanMessage(content='请问今天杭州和南昌哪里更冷？', additional_kwargs={}, response_metadata={}, id='76733179-acf4-4790-a55d-8b1a26b5989a'),
# ...

# %% [markdown]
# 接下来继续尝试进行工具的多步调用：

# %%
import os
from datetime import datetime

# %%
@tool
def write_file(content: str) -> str:
    """
    将指定内容写入本地文件。
    :param content: 必要参数，字符串类型，用于表示需要写入文档的具体内容。
    :return: 写入结果提示信息。
    """
    try:
        # ✅ 始终先定义文件名（防止未绑定变量）
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        filename = f"output_{timestamp}.txt"

        # 写入文件
        with open(filename, "w", encoding="utf-8") as f:
            f.write(content)

        abs_path = os.path.abspath(filename)
        return f"✅ 已成功写入本地文件：{abs_path}"

    except Exception as e:
        return f"❌ 文件写入失败：{str(e)}"

# %%
agent = create_agent(
    model=model,
    tools=[get_weather, write_file],
    system_prompt="你是一名多才多艺的智能助手，可以调用工具帮助用户解决问题。"
)

# %%
result = agent.invoke(
    {"messages": [{"role": "user", "content": "请帮我查询天津、石家庄、上海等地天气，并写入本地文件。"}]}
)

# %%
result['messages'][-1].content
# Out:
# '完成！我已经成功查询了天津、石家庄和上海的天气信息，并将详细报告写入了本地文件。以下是查询结果的简要总结：\n\n**天气查询结果：**\n\n1. **天津**：晴，-1.03°C，体感-3.66°C，湿度21%，风速2m/s\n2. **石家庄**：多云，1.61°C，体感-0.39°C，湿度18%，风速1.84m/s  \n3. **上海**：多云，13.92°C，体感12.78°C，湿度54%，风速6m/s\n\n**主要发现：**\n- 上海最温暖（13.92°C），天津最冷（-1.03°C）\n- 上海湿度最高（54%），天津和石家庄较为干燥\n- 上海风速最大（6m/s）\n\n完整的详细报告已保存到本地文件中，包含了每个城市的详细天气参数、对比分析和出行建议。'

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/image-20251202163004568.png" alt="image-20251202163004568" style="zoom:33%;" />

# %% [markdown]
# 而此时就经历了两轮Function calling，也就是先查询天气、然后写入到本地文件中。

# %%
len(result['messages'])
# Out:
# 10

# %%
result['messages']
# Out:
# [HumanMessage(content='请帮我查询天津、石家庄、上海等地天气，并写入本地文件。', additional_kwargs={}, response_metadata={}, id='907d8b72-3a60-4308-ac24-a78cfcda1782'),
# ...

# %% [markdown]
# 而如果出现调用工具报错，则一般会尝试2-3次之后停止尝试。此外，关于调用工具报错信息的输出格式、以及控制报错响应流程，都可以使用稍后介绍的中间件来完成。

# %% [markdown]
# ### 4.搭建基于DeepSeek-V3.2 reasoner的Agent流程

# %% [markdown]
# - 正常情况下调用会报错，因为目前LangChain 1.1还未兼容DeepSeek-V3.2的推理调用工具流程

# %%
model = ChatDeepSeek(model="deepseek-reasoner")

agent = create_agent(
    model=model,
    tools=[get_weather],
    system_prompt="你是一名多才多艺的智能助手，可以调用工具帮助用户解决问题。"
)

# %%
result = agent.invoke(
    {"messages": [{"role": "user", "content": "请问北京今天天气如何？"}]}
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 result = agent.invoke(
#       2     {"messages": [{"role": "user", "content": "请问北京今天天气如何？"}]}
#       3 )
#
# File C:\ProgramData\anaconda3\envs\langchain\Lib\site-packages\langgraph\pregel\main.py:3068, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3065 chunks: list[dict[str, Any] | Any] = []
#    3066 interrupts: list[Interrupt] = []
# -> 3068 for chunk in self.stream(
#    3069     input,
#    3070     config,
#    3071     context=context,
#    3072     stream_mode=["updates", "values"]
#    3073     if stream_mode == "values"
#    3074     else stream_mode,
#    3075     print_mode=print_mode,
#    3076     output_keys=output_keys,
#    3077     interrupt_before=interrupt_before,
# ...

# %% [markdown]
# 解决方案概览
#
# 通过继承 `BaseChatModel` 创建自定义的 `DeepSeekReasonerChatModel`，实现：
#
# 1. 与 LangChain 1.0 的 `create_agent` 完全兼容
# 2. 正确处理 `reasoning_content` 字段
# 3. 支持完整的工具调用流程
# 4. 可以查看模型的推理过程

# %% [markdown]
# - 创建核心类：DeepSeekReasonerChatModel

# %%
from typing import Optional, List, Dict, Any
from langchain_core.language_models.chat_models import BaseChatModel

class DeepSeekReasonerChatModel(BaseChatModel):
    """
    自定义 DeepSeek Reasoner 模型

    关键特性：
    1. 保留 reasoning_content 在 additional_kwargs 中
    2. 消息转换时恢复 reasoning_content
    3. 完整支持工具绑定和调用
    """

    api_key: str
    base_url: str = "https://api.deepseek.com"
    model_name: str = "deepseek-reasoner"
    temperature: float = 0.7
    bound_tools: Optional[List[Dict]] = None

# %% [markdown]
# - 创建关键方法：`_convert_messages_to_openai_format`

# %%
def _convert_messages_to_openai_format(self, messages):
    """LangChain 消息 → OpenAI 格式"""
    openai_messages = []

    for msg in messages:
        if isinstance(msg, AIMessage):
            msg_dict = {
                "role": "assistant",
                "content": msg.content or "",
            }

            # 添加 tool_calls
            if msg.tool_calls:
                msg_dict["tool_calls"] = [...]

            # 【关键】恢复 reasoning_content
            if 'reasoning_content' in msg.additional_kwargs:
                msg_dict["reasoning_content"] = msg.additional_kwargs['reasoning_content']

            openai_messages.append(msg_dict)

    return openai_messages

# %% [markdown]
# - 优化响应处理：`_create_ai_message_from_response`

# %%
def _create_ai_message_from_response(self, response):
    """OpenAI 响应 → LangChain AIMessage"""
    message = response.choices[0].message

    # 处理 tool_calls
    tool_calls = [...]

    # 【关键】保存 reasoning_content 到 additional_kwargs
    additional_kwargs = {}
    if hasattr(message, 'reasoning_content'):
        additional_kwargs['reasoning_content'] = message.reasoning_content

    return AIMessage(
        content=message.content or "",
        tool_calls=tool_calls if tool_calls else None,  # 不能是 None
        additional_kwargs=additional_kwargs
    )

# %% [markdown]
# - 进行工具绑定：`bind_tools`

# %%
from langchain_core.tools import BaseTool
def bind_tools(self, tools: List[BaseTool], **kwargs):
    """绑定 LangChain 工具"""
    # 转换为 OpenAI 格式
    openai_tools = []
    for tool in tools:
        openai_tools.append({
            "type": "function",
            "function": {
                "name": tool.name,
                "description": tool.description,
                "parameters": tool.args_schema.model_json_schema()
            }
        })

    # 返回新实例
    return self.__class__(
        api_key=self.api_key,
        base_url=self.base_url,
        model_name=self.model_name,
        temperature=self.temperature,
        bound_tools=openai_tools,  # 保存绑定的工具
        **kwargs
    )

# %% [markdown]
# - 优化生成响应格式：`_generate`

# %%
def _generate(self, messages, stop=None, run_manager=None, **kwargs):
    """核心生成方法"""
    # 转换消息
    openai_messages = self._convert_messages_to_openai_format(messages)

    # 准备请求
    request_params = {
        "model": self.model_name,
        "messages": openai_messages,
        "temperature": self.temperature,
    }

    # 添加工具
    if self.bound_tools:
        request_params["tools"] = self.bound_tools

    # 调用 API
    response = self._client.chat.completions.create(**request_params)

    # 创建响应
    ai_message = self._create_ai_message_from_response(response)

    return ChatResult(generations=[ChatGeneration(message=ai_message)])

# %% [markdown]
# - 实际调用效果

# %% [markdown]
# <center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/image-20251203195047325.png" alt="image-20251203195047325" style="zoom:50%;" />

# %% [markdown]
# <center><center><img src="https://ml2022.oss-cn-hangzhou.aliyuncs.com/img/0.png" alt="0" style="zoom:50%;" />

# %%
import os
from dotenv import load_dotenv
from langchain_core.tools import tool
from langchain.agents import create_agent

load_dotenv()
# 导入自定义模型
from deepseek_reasoner_chat_model import DeepSeekReasonerChatModel

# %%
# 创建自定义模型
model = DeepSeekReasonerChatModel(
    api_key=os.environ.get("DEEPSEEK_API_KEY"),
    model_name="deepseek-reasoner",
    temperature=0.7
)

# %%
tools = [get_weather, write_file]

# %%
agent = create_agent(
    model=model,
    tools=tools,
    system_prompt="你是一个有用的助手，可以使用工具来回答问题。"
)

# %%
result = agent.invoke(
    {"messages": [{"role": "user", "content": "请帮我查询北京天气信息。"}]}
)

# %%
result['messages'][-1].content
# Out:
# '根据查询结果，北京市当前天气信息如下：\n\n**天气状况：** 晴朗\n**当前温度：** -4.06°C\n**体感温度：** -7.17°C\n**最低/最高温度：** -4.06°C / -4.06°C\n**气压：** 1027 hPa\n**湿度：** 17%\n**风速：** 1.99 m/s（南风）\n**阵风：** 4.32 m/s\n**能见度：** 10公里\n**云量：** 1%\n\n**温馨提示：** 目前北京天气非常寒冷，气温在零下4度左右，体感温度更低（零下7度）。建议外出时穿戴厚实的羽绒服、帽子、手套等防寒衣物，注意保暖防冻。天气晴朗，能见度良好，但风力不大。'

# %%
result['messages']
# Out:
# [HumanMessage(content='请帮我查询北京天气信息。', additional_kwargs={}, response_metadata={}, id='4266bd07-163f-49d4-bc5a-2faa8baedb62'),
#  AIMessage(content='', additional_kwargs={'reasoning_content': '用户想查询北京的天气信息。我需要使用get_weather工具，并传入参数loc="Beijing"。现在来调用这个函数。'}, response_metadata={}, id='lc_run--8ef7f389-8feb-4552-924d-e48a95e3020c-0', tool_calls=[{'name': 'get_weather', 'args': {'loc': 'Beijing'}, 'id': 'call_00_fZSDCV1Ho3wdnExId1TxC9oz', 'type': 'tool_call'}]),
# ...

# %%
# 调用 agent
result = agent.invoke({
    "messages": [("user", "请问北京和沈阳哪里更冷？")]
})

# 查看结果
for msg in result["messages"]:
    if hasattr(msg, 'content') and msg.content:
        print(f"AI: {msg.content}")

        # 查看推理过程
        if hasattr(msg, 'additional_kwargs') and 'reasoning_content' in msg.additional_kwargs:
            print(f"推理: {msg.additional_kwargs['reasoning_content'][:200]}...")
# Out:
# AI: 请问北京和沈阳哪里更冷？
# AI: {"coord": {"lon": 116.3972, "lat": 39.9075}, "weather": [{"id": 800, "main": "Clear", "description": "\u6674", "icon": "01n"}], "base": "stations", "main": {"temp": -4.06, "feels_like": -7.17, "temp_min": -4.06, "temp_max": -4.06, "pressure": 1027, "humidity": 17, "sea_level": 1027, "grnd_level": 1022}, "visibility": 10000, "wind": {"speed": 1.99, "deg": 196, "gust": 4.32}, "clouds": {"all": 1}, "dt": 1764761901, "sys": {"type": 1, "id": 9609, "country": "CN", "sunrise": 1764717520, "sunset": 1764751796}, "timezone": 28800, "id": 1816670, "name": "Beijing", "cod": 200}
# ...
